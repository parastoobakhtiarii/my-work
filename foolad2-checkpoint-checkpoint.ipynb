# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel (r'C:\Users\Parastoo\OneDrive\Desktop\foolad.xlsx')

# %%
data
# Out:
#           Date   Open   High    Low  Close    Volume
# 0     20220622  11460  11550  11310  11440  43038062
# 1     20220621  11580  11610  11460  11550  42656631
# 2     20220620  11590  11740  11580  11620  49782910
# 3     20220619  11660  11740  11560  11610  45368856
# 4     20220618  11650  11750  11550  11610  60658889
# ...        ...    ...    ...    ...    ...       ...
# 2387  20120627   2507   2508   2507   2507  16387602
# 2388  20120626   2525   2527   2525   2611   1385197
# 2389  20120625   2565   2660   2559   2630   2815592
# 2390  20120624   2664   2680   2664   2665  10856112
# 2391  20120623   2671   2671   2671   2775    458410
#
# [2392 rows x 6 columns]

# %%
from stockstats import StockDataFrame as Sdf

# %%
stock = Sdf.retype(data)

# %%
data['macd']=stock['macd']
data.sort_values(by=['date'], inplace=True, ascending=False)
data
# Out:
#            open   high    low  close    volume       macd      macds  \
# date
# 20220622  11460  11550  11310  11440  43038062   0.000000   0.000000
# 20220621  11580  11610  11460  11550  42656631   2.467949   1.371083
# 20220620  11590  11740  11580  11620  49782910   5.315352   2.987587
# 20220619  11660  11740  11560  11610  45368856   6.119095   4.048396
# 20220618  11650  11750  11550  11610  60658889   6.427015   4.755981
# ...         ...    ...    ...    ...       ...        ...        ...
# 20120627   2507   2508   2507   2507  16387602  58.790778  52.598457
# 20120626   2525   2527   2525   2611   1385197  65.248794  55.128525
# 20120625   2565   2660   2559   2630   2815592  71.080587  58.318937
# 20120624   2664   2680   2664   2665  10856112  77.631643  62.181478
# 20120623   2671   2671   2671   2775    458410  90.654474  67.876077
#
#               macdh
# date
# 20220622   0.000000
# 20220621   1.096866
# 20220620   2.327766
# 20220619   2.070700
# 20220618   1.671034
# ...             ...
# 20120627   6.192321
# 20120626  10.120269
# 20120625  12.761649
# 20120624  15.450164
# 20120623  22.778397
#
# [2392 rows x 8 columns]

# %%
data['rsi']=stock['rsi']

# %%
data
# Out:
#            open   high    low  close    volume       macd      macds  \
# date
# 20220622  11460  11550  11310  11440  43038062   0.000000   0.000000
# 20220621  11580  11610  11460  11550  42656631   2.467949   1.371083
# 20220620  11590  11740  11580  11620  49782910   5.315352   2.987587
# 20220619  11660  11740  11560  11610  45368856   6.119095   4.048396
# 20220618  11650  11750  11550  11610  60658889   6.427015   4.755981
# ...         ...    ...    ...    ...       ...        ...        ...
# 20120627   2507   2508   2507   2507  16387602  58.790778  52.598457
# 20120626   2525   2527   2525   2611   1385197  65.248794  55.128525
# 20120625   2565   2660   2559   2630   2815592  71.080587  58.318937
# 20120624   2664   2680   2664   2665  10856112  77.631643  62.181478
# 20120623   2671   2671   2671   2775    458410  90.654474  67.876077
#
#               macdh         rsi
# date
# 20220622   0.000000         NaN
# 20220621   1.096866  100.000000
# 20220620   2.327766  100.000000
# 20220619   2.070700   94.112346
# 20220618   1.671034   94.112346
# ...             ...         ...
# 20120627   6.192321   68.411732
# 20120626  10.120269   77.692676
# 20120625  12.761649   78.911702
# 20120624  15.450164   80.974259
# 20120623  22.778397   85.706055
#
# [2392 rows x 9 columns]

# %%
data['wr_12']=stock['wr_12']

# %%
data['open_2_sma'] = stock['open_2_sma']
data
# Out:
#            open   high    low  close    volume       macd      macds  \
# date
# 20220622  11460  11550  11310  11440  43038062   0.000000   0.000000
# 20220621  11580  11610  11460  11550  42656631   2.467949   1.371083
# 20220620  11590  11740  11580  11620  49782910   5.315352   2.987587
# 20220619  11660  11740  11560  11610  45368856   6.119095   4.048396
# 20220618  11650  11750  11550  11610  60658889   6.427015   4.755981
# ...         ...    ...    ...    ...       ...        ...        ...
# 20120627   2507   2508   2507   2507  16387602  58.790778  52.598457
# 20120626   2525   2527   2525   2611   1385197  65.248794  55.128525
# 20120625   2565   2660   2559   2630   2815592  71.080587  58.318937
# 20120624   2664   2680   2664   2665  10856112  77.631643  62.181478
# 20120623   2671   2671   2671   2775    458410  90.654474  67.876077
#
#               macdh         rsi      wr_12  open_2_sma
# date
# 20220622   0.000000         NaN -45.833333     11460.0
# 20220621   1.096866  100.000000 -20.000000     11520.0
# 20220620   2.327766  100.000000 -27.906977     11585.0
# 20220619   2.070700   94.112346 -30.232558     11625.0
# 20220618   1.671034   94.112346 -31.818182     11655.0
# ...             ...         ...        ...         ...
# 20120627   6.192321   68.411732 -37.656904      2532.0
# 20120626  10.120269   77.692676   5.857741      2516.0
# 20120625  12.761649   78.911702  -9.933775      2545.0
# 20120624  15.450164   80.974259  -4.658385      2614.5
# 20120623  22.778397   85.706055  34.926471      2667.5
#
# [2392 rows x 11 columns]

# %%
data.replace([np.inf, -np.inf], np.nan)
data.dropna()
# Out:
#            open   high    low  close    volume       macd      macds  \
# date
# 20220621  11580  11610  11460  11550  42656631   2.467949   1.371083
# 20220620  11590  11740  11580  11620  49782910   5.315352   2.987587
# 20220619  11660  11740  11560  11610  45368856   6.119095   4.048396
# 20220618  11650  11750  11550  11610  60658889   6.427015   4.755981
# 20220615  11730  11990  11580  11710  38764404  10.767368   6.385401
# ...         ...    ...    ...    ...       ...        ...        ...
# 20120627   2507   2508   2507   2507  16387602  58.790778  52.598457
# 20120626   2525   2527   2525   2611   1385197  65.248794  55.128525
# 20120625   2565   2660   2559   2630   2815592  71.080587  58.318937
# 20120624   2664   2680   2664   2665  10856112  77.631643  62.181478
# 20120623   2671   2671   2671   2775    458410  90.654474  67.876077
#
#               macdh         rsi      wr_12  open_2_sma
# date
# 20220621   1.096866  100.000000 -20.000000     11520.0
# 20220620   2.327766  100.000000 -27.906977     11585.0
# 20220619   2.070700   94.112346 -30.232558     11625.0
# 20220618   1.671034   94.112346 -31.818182     11655.0
# 20220615   4.381967   96.501335 -41.176471     11690.0
# ...             ...         ...        ...         ...
# 20120627   6.192321   68.411732 -37.656904      2532.0
# 20120626  10.120269   77.692676   5.857741      2516.0
# 20120625  12.761649   78.911702  -9.933775      2545.0
# 20120624  15.450164   80.974259  -4.658385      2614.5
# 20120623  22.778397   85.706055  34.926471      2667.5
#
# [2391 rows x 11 columns]

# %%
data.isnull().any()
# Out:
# open          False
# high          False
# low           False
# close         False
# volume        False
# macd          False
# macds         False
# macdh         False
# rsi            True
# wr_12         False
# open_2_sma    False
# dtype: bool

# %%
#Drop rows with NaN values
data['open'].dropna()
data.describe()
data = data.dropna(subset=['open'])
data = data.dropna(subset=['high'])
data = data.dropna(subset=['low'])
data = data.dropna(subset=['close'])
#data = data.dropna(subset=['adj close*'])
data = data.dropna(subset=['volume'])
data = data.dropna(subset=['macd'])
data = data.dropna(subset=['rsi'])
data = data.dropna(subset=['wr_12'])
data = data.dropna(subset=['open_2_sma'])
data.isnull().any()
# Out:
# open          False
# high          False
# low           False
# close         False
# volume        False
# macd          False
# macds         False
# macdh         False
# rsi           False
# wr_12         False
# open_2_sma    False
# dtype: bool

# %%
from keras.layers import Dense, Dropout, Activation, LSTM, Convolution1D, MaxPooling1D, Flatten
from keras.models import Sequential

# %%
data= data.values[:, 1:5]
print (data.shape)
# Out:
# (2391, 4)

# %%
print (data[:6, :])
# Out:
# [[1.1610000e+04 1.1460000e+04 1.1550000e+04 4.2656631e+07]
#  [1.1740000e+04 1.1580000e+04 1.1620000e+04 4.9782910e+07]
#  [1.1740000e+04 1.1560000e+04 1.1610000e+04 4.5368856e+07]
#  [1.1750000e+04 1.1550000e+04 1.1610000e+04 6.0658889e+07]
#  [1.1990000e+04 1.1580000e+04 1.1710000e+04 3.8764404e+07]
#  [1.1910000e+04 1.1640000e+04 1.1820000e+04 6.6911238e+07]]

# %%
y= data[1:, 3]
print (y.shape)
X= data[:2390,:]
print (X.shape)
# Out:
# (2390,)
# (2390, 4)

# %%
y= (y- min(y))/(max(y)- min(y))
print (y[2390:])
print (y[:7])
# Out:
# []
# [0.04605409 0.04197066 0.05611544 0.03586089 0.06189948 0.09885506
#  0.06603217]

# %%
X= (X- np.min(X,axis=0))/(np.max(X, axis=0)-np.min(X,axis=0))
print (X.shape)
print (X[:3, :])
# Out:
# (2390, 4)
# [[0.46776793 0.50043668 0.46596581 0.03946158]
#  [0.47300564 0.50567686 0.46905782 0.04605409]
#  [0.47300564 0.50480349 0.4686161  0.04197066]]

# %%
time_steps= 100
X_new= np.zeros((X.shape[0] - time_steps +1, 100, X.shape[1]))
y_new= np.zeros((y.shape[0] -time_steps +1,))
for ix in range(X_new.shape[0]):
    for jx in range(time_steps):
        X_new[ix, jx, :]= X[ix +jx, :]
    y_new[ix]= y[ix + time_steps -1]
print (X_new.shape, y_new.shape)
# Out:
# (2291, 100, 4) (2291,)

# %%
split = int(0.95*data.shape[0])
X_train = X_new[:split]
X_test = X_new[split:]

y_train = y_new[:split]
y_test = y_new[split:]

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (2271, 100, 4) (2271,)
# (20, 100, 4) (20,)

# %%
model = Sequential()
model.add(Convolution1D(64, 3, padding='same',input_shape= (100,4)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.2))
model.add(Convolution1D(32, 3, padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(units=1))
model.add(Activation('linear'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 100, 64)           832
#
#  max_pooling1d (MaxPooling1D  (None, 50, 64)           0
#  )
#
#  lstm (LSTM)                 (None, 50, 100)           66000
#
#  dropout (Dropout)           (None, 50, 100)           0
#
#  conv1d_1 (Conv1D)           (None, 50, 32)            9632
#
#  max_pooling1d_1 (MaxPooling  (None, 25, 32)           0
#  1D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 1)                 801
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 77,265
# Trainable params: 77,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=256, epochs=75, validation_data = (X_test, y_test), verbose=2)
# Out:
# Epoch 1/75
# 9/9 - 5s - loss: 0.0126 - accuracy: 0.0599 - val_loss: 7.0841e-04 - val_accuracy: 0.2000 - 5s/epoch - 529ms/step
# Epoch 2/75
# 9/9 - 1s - loss: 0.0067 - accuracy: 0.0608 - val_loss: 3.0249e-04 - val_accuracy: 0.2000 - 1s/epoch - 163ms/step
# Epoch 3/75
# 9/9 - 1s - loss: 0.0059 - accuracy: 0.0608 - val_loss: 1.7830e-04 - val_accuracy: 0.2000 - 1s/epoch - 159ms/step
# Epoch 4/75
# 9/9 - 1s - loss: 0.0053 - accuracy: 0.0608 - val_loss: 1.9641e-04 - val_accuracy: 0.2000 - 1s/epoch - 163ms/step
# Epoch 5/75
# 9/9 - 1s - loss: 0.0050 - accuracy: 0.0608 - val_loss: 1.4355e-04 - val_accuracy: 0.2000 - 1s/epoch - 156ms/step
# Epoch 6/75
# 9/9 - 1s - loss: 0.0052 - accuracy: 0.0608 - val_loss: 1.1732e-04 - val_accuracy: 0.2000 - 1s/epoch - 137ms/step
# Epoch 7/75
# 9/9 - 1s - loss: 0.0050 - accuracy: 0.0608 - val_loss: 1.1739e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 8/75
# 9/9 - 1s - loss: 0.0050 - accuracy: 0.0608 - val_loss: 9.6485e-05 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 9/75
# 9/9 - 1s - loss: 0.0050 - accuracy: 0.0608 - val_loss: 1.1230e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 10/75
# 9/9 - 1s - loss: 0.0047 - accuracy: 0.0608 - val_loss: 1.0177e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 11/75
# 9/9 - 1s - loss: 0.0049 - accuracy: 0.0608 - val_loss: 1.1139e-04 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 12/75
# 9/9 - 1s - loss: 0.0048 - accuracy: 0.0608 - val_loss: 1.1769e-04 - val_accuracy: 0.2000 - 1s/epoch - 141ms/step
# Epoch 13/75
# 9/9 - 1s - loss: 0.0047 - accuracy: 0.0608 - val_loss: 1.1224e-04 - val_accuracy: 0.2000 - 1s/epoch - 130ms/step
# Epoch 14/75
# 9/9 - 1s - loss: 0.0049 - accuracy: 0.0608 - val_loss: 1.1045e-04 - val_accuracy: 0.2000 - 1s/epoch - 130ms/step
# Epoch 15/75
# 9/9 - 1s - loss: 0.0047 - accuracy: 0.0608 - val_loss: 1.2657e-04 - val_accuracy: 0.2000 - 1s/epoch - 130ms/step
# Epoch 16/75
# 9/9 - 1s - loss: 0.0050 - accuracy: 0.0608 - val_loss: 1.5146e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 17/75
# 9/9 - 1s - loss: 0.0049 - accuracy: 0.0608 - val_loss: 1.7305e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 18/75
# 9/9 - 1s - loss: 0.0048 - accuracy: 0.0608 - val_loss: 1.1015e-04 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 19/75
# 9/9 - 1s - loss: 0.0047 - accuracy: 0.0608 - val_loss: 1.2336e-04 - val_accuracy: 0.2000 - 1s/epoch - 130ms/step
# Epoch 20/75
# 9/9 - 1s - loss: 0.0047 - accuracy: 0.0608 - val_loss: 1.6645e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 21/75
# 9/9 - 1s - loss: 0.0048 - accuracy: 0.0608 - val_loss: 1.0542e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 22/75
# 9/9 - 1s - loss: 0.0045 - accuracy: 0.0608 - val_loss: 1.1346e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 23/75
# 9/9 - 1s - loss: 0.0045 - accuracy: 0.0608 - val_loss: 1.2926e-04 - val_accuracy: 0.2000 - 1s/epoch - 130ms/step
# Epoch 24/75
# 9/9 - 1s - loss: 0.0047 - accuracy: 0.0608 - val_loss: 1.3195e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 25/75
# 9/9 - 1s - loss: 0.0047 - accuracy: 0.0608 - val_loss: 2.8153e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 26/75
# 9/9 - 1s - loss: 0.0045 - accuracy: 0.0608 - val_loss: 1.7726e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 27/75
# 9/9 - 1s - loss: 0.0044 - accuracy: 0.0608 - val_loss: 1.6306e-04 - val_accuracy: 0.2000 - 1s/epoch - 125ms/step
# Epoch 28/75
# 9/9 - 1s - loss: 0.0044 - accuracy: 0.0608 - val_loss: 1.5005e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 29/75
# 9/9 - 1s - loss: 0.0047 - accuracy: 0.0608 - val_loss: 1.6512e-04 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 30/75
# 9/9 - 1s - loss: 0.0045 - accuracy: 0.0608 - val_loss: 1.1791e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 31/75
# 9/9 - 1s - loss: 0.0046 - accuracy: 0.0608 - val_loss: 1.7112e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 32/75
# 9/9 - 1s - loss: 0.0045 - accuracy: 0.0608 - val_loss: 1.4203e-04 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 33/75
# 9/9 - 1s - loss: 0.0044 - accuracy: 0.0608 - val_loss: 1.7617e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 34/75
# 9/9 - 1s - loss: 0.0044 - accuracy: 0.0608 - val_loss: 1.1891e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 35/75
# 9/9 - 1s - loss: 0.0042 - accuracy: 0.0608 - val_loss: 1.4258e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 36/75
# 9/9 - 1s - loss: 0.0042 - accuracy: 0.0608 - val_loss: 1.1325e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 37/75
# 9/9 - 1s - loss: 0.0043 - accuracy: 0.0608 - val_loss: 1.2896e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 38/75
# 9/9 - 1s - loss: 0.0043 - accuracy: 0.0608 - val_loss: 1.3469e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 39/75
# 9/9 - 1s - loss: 0.0044 - accuracy: 0.0608 - val_loss: 1.1149e-04 - val_accuracy: 0.2000 - 1s/epoch - 130ms/step
# Epoch 40/75
# 9/9 - 1s - loss: 0.0042 - accuracy: 0.0608 - val_loss: 1.1131e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 41/75
# 9/9 - 1s - loss: 0.0041 - accuracy: 0.0608 - val_loss: 1.4088e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 42/75
# 9/9 - 1s - loss: 0.0043 - accuracy: 0.0608 - val_loss: 1.1469e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 43/75
# 9/9 - 1s - loss: 0.0043 - accuracy: 0.0608 - val_loss: 1.2493e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 44/75
# 9/9 - 1s - loss: 0.0043 - accuracy: 0.0608 - val_loss: 1.4675e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 45/75
# 9/9 - 1s - loss: 0.0042 - accuracy: 0.0608 - val_loss: 1.1068e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 46/75
# 9/9 - 1s - loss: 0.0039 - accuracy: 0.0608 - val_loss: 1.0715e-04 - val_accuracy: 0.2000 - 1s/epoch - 130ms/step
# Epoch 47/75
# 9/9 - 1s - loss: 0.0040 - accuracy: 0.0608 - val_loss: 1.0957e-04 - val_accuracy: 0.2000 - 1s/epoch - 133ms/step
# Epoch 48/75
# 9/9 - 1s - loss: 0.0041 - accuracy: 0.0608 - val_loss: 1.3803e-04 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 49/75
# 9/9 - 1s - loss: 0.0040 - accuracy: 0.0608 - val_loss: 1.0457e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 50/75
# 9/9 - 1s - loss: 0.0041 - accuracy: 0.0608 - val_loss: 1.0855e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 51/75
# 9/9 - 1s - loss: 0.0039 - accuracy: 0.0608 - val_loss: 1.2895e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 52/75
# 9/9 - 1s - loss: 0.0040 - accuracy: 0.0608 - val_loss: 1.0832e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 53/75
# 9/9 - 1s - loss: 0.0041 - accuracy: 0.0608 - val_loss: 1.0395e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 54/75
# 9/9 - 1s - loss: 0.0039 - accuracy: 0.0608 - val_loss: 1.0857e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 55/75
# 9/9 - 1s - loss: 0.0040 - accuracy: 0.0608 - val_loss: 1.3508e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step
# Epoch 56/75
# 9/9 - 1s - loss: 0.0039 - accuracy: 0.0608 - val_loss: 9.8241e-05 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 57/75
# 9/9 - 1s - loss: 0.0038 - accuracy: 0.0608 - val_loss: 1.0391e-04 - val_accuracy: 0.2000 - 1s/epoch - 131ms/step
# Epoch 58/75
# 9/9 - 1s - loss: 0.0038 - accuracy: 0.0612 - val_loss: 9.8161e-05 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 59/75
# 9/9 - 1s - loss: 0.0037 - accuracy: 0.0608 - val_loss: 1.0261e-04 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 60/75
# 9/9 - 1s - loss: 0.0038 - accuracy: 0.0608 - val_loss: 1.1685e-04 - val_accuracy: 0.2000 - 1s/epoch - 130ms/step
# Epoch 61/75
# 9/9 - 1s - loss: 0.0038 - accuracy: 0.0612 - val_loss: 1.0792e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 62/75
# 9/9 - 1s - loss: 0.0039 - accuracy: 0.0612 - val_loss: 1.2644e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 63/75
# 9/9 - 1s - loss: 0.0038 - accuracy: 0.0608 - val_loss: 1.4206e-04 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 64/75
# 9/9 - 1s - loss: 0.0035 - accuracy: 0.0612 - val_loss: 1.4718e-04 - val_accuracy: 0.2000 - 1s/epoch - 132ms/step
# Epoch 65/75
# 9/9 - 1s - loss: 0.0038 - accuracy: 0.0612 - val_loss: 1.1229e-04 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 66/75
# 9/9 - 1s - loss: 0.0038 - accuracy: 0.0612 - val_loss: 9.6440e-05 - val_accuracy: 0.2000 - 1s/epoch - 129ms/step
# Epoch 67/75
# 9/9 - 1s - loss: 0.0037 - accuracy: 0.0612 - val_loss: 1.2246e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 68/75
# 9/9 - 1s - loss: 0.0036 - accuracy: 0.0612 - val_loss: 1.1651e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 69/75
# 9/9 - 1s - loss: 0.0036 - accuracy: 0.0612 - val_loss: 1.6434e-04 - val_accuracy: 0.2000 - 1s/epoch - 127ms/step
# Epoch 70/75
# 9/9 - 1s - loss: 0.0036 - accuracy: 0.0612 - val_loss: 1.0567e-04 - val_accuracy: 0.2000 - 1s/epoch - 125ms/step
# Epoch 71/75
# 9/9 - 1s - loss: 0.0035 - accuracy: 0.0612 - val_loss: 1.2676e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 72/75
# 9/9 - 1s - loss: 0.0034 - accuracy: 0.0612 - val_loss: 1.1032e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 73/75
# 9/9 - 1s - loss: 0.0035 - accuracy: 0.0612 - val_loss: 1.1534e-04 - val_accuracy: 0.2000 - 1s/epoch - 124ms/step
# Epoch 74/75
# 9/9 - 1s - loss: 0.0034 - accuracy: 0.0612 - val_loss: 1.9678e-04 - val_accuracy: 0.2000 - 1s/epoch - 126ms/step
# Epoch 75/75
# 9/9 - 1s - loss: 0.0035 - accuracy: 0.0612 - val_loss: 1.1711e-04 - val_accuracy: 0.2000 - 1s/epoch - 128ms/step

# %%
score= model.evaluate(X_test, y_test, batch_size=256)
# Out:
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1711e-04 - accuracy: 0.2000

# %%
print (score)
# Out:
# [0.00011710634862538427, 0.20000000298023224]

# %%
y_pred= model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 645ms/step

# %%
plt.plot(y_pred, 'r-')
plt.plot(y_test, 'b-')
plt.show()

# %%
import math

# %%
MSE = np.square(np.subtract(y_test,y_pred)).mean() 
print (MSE)
# Out:
# 0.00015452048546184586

# %%
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 0.012430626913468438

# %%
def mae(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs(y_test - y_pred))
print(mae(y_test, y_pred))
# Out:
# 0.00884773987729585

# %%
plt.plot (y_pred, y_test, 'bo')
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.show()
