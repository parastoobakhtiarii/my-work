# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel (r'C:\Users\Parastoo\OneDrive\Desktop\vghadir.xlsx')

# %%
data
# Out:
#           Date  Close   Open   High    Low    Volume
# 0     20220622  14550  14500  14680  14370  12945776
# 1     20220621  14670  14900  14900  14570   7704388
# 2     20220620  14840  14740  15000  14740  19205462
# 3     20220619  14810  15050  15050  14730  13284086
# 4     20220618  14800  14970  14990  14710   9522163
# ...        ...    ...    ...    ...    ...       ...
# 3428  20070723   2365   2318   2365   2318      1610
# 3429  20070722   2365   2318   2365   2318      1010
# 3430  20070717   2365   2318   2365   2318        74
# 3431  20070626   2365   2318   2365   2318      5010
# 3432  20070623   2365   2318   2365   2318        33
#
# [3433 rows x 6 columns]

# %%
data= data.dropna(axis=0)
data.tail()
# Out:
#           Date  Close  Open  High   Low  Volume
# 3428  20070723   2365  2318  2365  2318    1610
# 3429  20070722   2365  2318  2365  2318    1010
# 3430  20070717   2365  2318  2365  2318      74
# 3431  20070626   2365  2318  2365  2318    5010
# 3432  20070623   2365  2318  2365  2318      33

# %%
from stockstats import StockDataFrame as Sdf

# %%
stock = Sdf.retype(data)

# %%
data['macd']=stock['macd']
data.sort_values(by=['date'], inplace=True, ascending=False)
data
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220622  14550  14500  14680  14370  12945776    0.000000    0.000000
# 20220621  14670  14900  14900  14570   7704388    2.692308    1.495726
# 20220620  14840  14740  15000  14740  19205462    8.702224    4.449209
# 20220619  14810  15050  15050  14730  13284086   10.139244    6.376728
# 20220618  14800  14970  14990  14710   9522163   10.308720    7.546406
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070723   2365   2318   2365   2318      1610  100.524595  112.555729
# 20070722   2365   2318   2365   2318      1010   95.325435  109.109670
# 20070717   2365   2318   2365   2318        74   90.165689  105.320874
# 20070626   2365   2318   2365   2318      5010   85.095624  101.275824
# 20070623   2365   2318   2365   2318        33   80.153600   97.051379
#
#               macdh
# date
# 20220622   0.000000
# 20220621   1.196581
# 20220620   4.253015
# 20220619   3.762516
# 20220618   2.762313
# ...             ...
# 20070723 -12.031134
# 20070722 -13.784236
# 20070717 -15.155185
# 20070626 -16.180200
# 20070623 -16.897779
#
# [3433 rows x 8 columns]

# %%
#data['rsi']=stock['rsi']
#data['rsi']=stock['rsi_14']

# %%
#data

# %%
data['CCI']=stock['cci']
#data['STCK%']=stock['kdjk']
#data['ADO'] = (data['high'] - data['close'])/(data['high']-data['low'])

# %%
data
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220622  14550  14500  14680  14370  12945776    0.000000    0.000000
# 20220621  14670  14900  14900  14570   7704388    2.692308    1.495726
# 20220620  14840  14740  15000  14740  19205462    8.702224    4.449209
# 20220619  14810  15050  15050  14730  13284086   10.139244    6.376728
# 20220618  14800  14970  14990  14710   9522163   10.308720    7.546406
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070723   2365   2318   2365   2318      1610  100.524595  112.555729
# 20070722   2365   2318   2365   2318      1010   95.325435  109.109670
# 20070717   2365   2318   2365   2318        74   90.165689  105.320874
# 20070626   2365   2318   2365   2318      5010   85.095624  101.275824
# 20070623   2365   2318   2365   2318        33   80.153600   97.051379
#
#               macdh        CCI
# date
# 20220622   0.000000        NaN
# 20220621   1.196581  66.666667
# 20220620   4.253015  93.421053
# 20220619   3.762516  67.599068
# 20220618   2.762313  44.093851
# ...             ...        ...
# 20070723 -12.031134  32.501248
# 20070722 -13.784236  17.283951
# 20070717 -15.155185 -35.897436
# 20070626 -16.180200 -35.897436
# 20070623 -16.897779 -35.897436
#
# [3433 rows x 9 columns]

# %%
#data['wr_12']=stock['wr_12']

# %%
data['open_2_sma'] = stock['open_2_sma']
data
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220622  14550  14500  14680  14370  12945776    0.000000    0.000000
# 20220621  14670  14900  14900  14570   7704388    2.692308    1.495726
# 20220620  14840  14740  15000  14740  19205462    8.702224    4.449209
# 20220619  14810  15050  15050  14730  13284086   10.139244    6.376728
# 20220618  14800  14970  14990  14710   9522163   10.308720    7.546406
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070723   2365   2318   2365   2318      1610  100.524595  112.555729
# 20070722   2365   2318   2365   2318      1010   95.325435  109.109670
# 20070717   2365   2318   2365   2318        74   90.165689  105.320874
# 20070626   2365   2318   2365   2318      5010   85.095624  101.275824
# 20070623   2365   2318   2365   2318        33   80.153600   97.051379
#
#               macdh        CCI  open_2_sma
# date
# 20220622   0.000000        NaN     14500.0
# 20220621   1.196581  66.666667     14700.0
# 20220620   4.253015  93.421053     14820.0
# 20220619   3.762516  67.599068     14895.0
# 20220618   2.762313  44.093851     15010.0
# ...             ...        ...         ...
# 20070723 -12.031134  32.501248      2341.5
# 20070722 -13.784236  17.283951      2318.0
# 20070717 -15.155185 -35.897436      2318.0
# 20070626 -16.180200 -35.897436      2318.0
# 20070623 -16.897779 -35.897436      2318.0
#
# [3433 rows x 10 columns]

# %%
data.replace([np.inf, -np.inf], np.nan)
data.dropna()
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220621  14670  14900  14900  14570   7704388    2.692308    1.495726
# 20220620  14840  14740  15000  14740  19205462    8.702224    4.449209
# 20220619  14810  15050  15050  14730  13284086   10.139244    6.376728
# 20220618  14800  14970  14990  14710   9522163   10.308720    7.546406
# 20220615  14990  15000  15100  14880  10105706   18.341339   10.472433
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070723   2365   2318   2365   2318      1610  100.524595  112.555729
# 20070722   2365   2318   2365   2318      1010   95.325435  109.109670
# 20070717   2365   2318   2365   2318        74   90.165689  105.320874
# 20070626   2365   2318   2365   2318      5010   85.095624  101.275824
# 20070623   2365   2318   2365   2318        33   80.153600   97.051379
#
#               macdh         CCI  open_2_sma
# date
# 20220621   1.196581   66.666667     14700.0
# 20220620   4.253015   93.421053     14820.0
# 20220619   3.762516   67.599068     14895.0
# 20220618   2.762313   44.093851     15010.0
# 20220615   7.868906  108.860759     14985.0
# ...             ...         ...         ...
# 20070723 -12.031134   32.501248      2341.5
# 20070722 -13.784236   17.283951      2318.0
# 20070717 -15.155185  -35.897436      2318.0
# 20070626 -16.180200  -35.897436      2318.0
# 20070623 -16.897779  -35.897436      2318.0
#
# [3429 rows x 10 columns]

# %%
data.isnull().any()
# Out:
# close         False
# open          False
# high          False
# low           False
# volume        False
# macd          False
# macds         False
# macdh         False
# CCI            True
# open_2_sma    False
# dtype: bool

# %%
#Drop rows with NaN values
#data['open'].dropna()
data.describe()
data = data.dropna(subset=['open'])
data = data.dropna(subset=['high'])
data = data.dropna(subset=['low'])
data = data.dropna(subset=['close'])
#data = data.dropna(subset=['adj close*'])
data = data.dropna(subset=['volume'])
data = data.dropna(subset=['macd'])
data = data.dropna(subset=['macds'])
data = data.dropna(subset=['macdh'])
#data = data.dropna(subset=['rsi'])
#data = data.dropna(subset=['wr_12'])
data = data.dropna(subset=['open_2_sma'])
data = data.dropna(subset=['CCI'])
#data = data.dropna(subset=['ADO'])
data.isnull().any()
# Out:
# close         False
# open          False
# high          False
# low           False
# volume        False
# macd          False
# macds         False
# macdh         False
# CCI           False
# open_2_sma    False
# dtype: bool

# %%
data= data.dropna(axis=0)
data= data.dropna(axis=1)
data.tail()
# Out:
#           close  open  high   low  volume        macd       macds      macdh  \
# date
# 20070723   2365  2318  2365  2318    1610  100.524595  112.555729 -12.031134
# 20070722   2365  2318  2365  2318    1010   95.325435  109.109670 -13.784236
# 20070717   2365  2318  2365  2318      74   90.165689  105.320874 -15.155185
# 20070626   2365  2318  2365  2318    5010   85.095624  101.275824 -16.180200
# 20070623   2365  2318  2365  2318      33   80.153600   97.051379 -16.897779
#
#                 CCI  open_2_sma
# date
# 20070723  32.501248      2341.5
# 20070722  17.283951      2318.0
# 20070717 -35.897436      2318.0
# 20070626 -35.897436      2318.0
# 20070623 -35.897436      2318.0

# %%
data.sort_values(by=['date'], inplace=True, ascending=False)
data
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220621  14670  14900  14900  14570   7704388    2.692308    1.495726
# 20220620  14840  14740  15000  14740  19205462    8.702224    4.449209
# 20220619  14810  15050  15050  14730  13284086   10.139244    6.376728
# 20220618  14800  14970  14990  14710   9522163   10.308720    7.546406
# 20220615  14990  15000  15100  14880  10105706   18.341339   10.472433
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070723   2365   2318   2365   2318      1610  100.524595  112.555729
# 20070722   2365   2318   2365   2318      1010   95.325435  109.109670
# 20070717   2365   2318   2365   2318        74   90.165689  105.320874
# 20070626   2365   2318   2365   2318      5010   85.095624  101.275824
# 20070623   2365   2318   2365   2318        33   80.153600   97.051379
#
#               macdh         CCI  open_2_sma
# date
# 20220621   1.196581   66.666667     14700.0
# 20220620   4.253015   93.421053     14820.0
# 20220619   3.762516   67.599068     14895.0
# 20220618   2.762313   44.093851     15010.0
# 20220615   7.868906  108.860759     14985.0
# ...             ...         ...         ...
# 20070723 -12.031134   32.501248      2341.5
# 20070722 -13.784236   17.283951      2318.0
# 20070717 -15.155185  -35.897436      2318.0
# 20070626 -16.180200  -35.897436      2318.0
# 20070623 -16.897779  -35.897436      2318.0
#
# [3429 rows x 10 columns]

# %%
#data.columns = [ 'high', 'low' ,'open' , 'macd' , 'macds' , 'macdh' , 'rsi'  , 'CCI'  , 'ADO' , 'open_sma' , 'wr_12', 'close' , 'volume'  ]
#data

# %%
from keras.layers import Dense, Dropout, Activation, LSTM, Convolution1D, MaxPooling1D, Flatten
from keras.models import Sequential

# %%
data= data.values[:, 0:10]
print (data.shape)
# Out:
# (3429, 10)

# %%
print (data[:10, :])
# Out:
# [[ 1.46700000e+04  1.49000000e+04  1.49000000e+04  1.45700000e+04
#    7.70438800e+06  2.69230769e+00  1.49572650e+00  1.19658120e+00
#    6.66666667e+01  1.47000000e+04]
#  [ 1.48400000e+04  1.47400000e+04  1.50000000e+04  1.47400000e+04
#    1.92054620e+07  8.70222422e+00  4.44920917e+00  4.25301505e+00
#    9.34210526e+01  1.48200000e+04]
#  [ 1.48100000e+04  1.50500000e+04  1.50500000e+04  1.47300000e+04
#    1.32840860e+07  1.01392441e+01  6.37672777e+00  3.76251630e+00
#    6.75990676e+01  1.48950000e+04]
#  [ 1.48000000e+04  1.49700000e+04  1.49900000e+04  1.47100000e+04
#    9.52216300e+06  1.03087195e+01  7.54640642e+00  2.76231312e+00
#    4.40938511e+01  1.50100000e+04]
#  [ 1.49900000e+04  1.50000000e+04  1.51000000e+04  1.48800000e+04
#    1.01057060e+07  1.83413389e+01  1.04724333e+01  7.86890557e+00
#    1.08860759e+02  1.49850000e+04]
#  [ 1.51500000e+04  1.53200000e+04  1.53400000e+04  1.50100000e+04
#    1.31001450e+07  3.04250824e+01  1.55219165e+01  1.49031659e+01
#    1.55087015e+02  1.51600000e+04]
#  [ 1.51500000e+04  1.45300000e+04  1.52200000e+04  1.45300000e+04
#    3.90296010e+07  3.80384084e+01  2.09330529e+01  1.71053555e+01
#    5.11357633e+01  1.49250000e+04]
#  [ 1.43600000e+04  1.40000000e+04  1.47800000e+04  1.40000000e+04
#    2.19844710e+07  3.53694732e+00  1.69144662e+01 -1.33775189e+01
#   -1.60164835e+02  1.42650000e+04]
#  [ 1.40500000e+04  1.39900000e+04  1.41500000e+04  1.39900000e+04
#    1.37351630e+07 -3.69568187e+01  4.84417117e+00 -4.18009899e+01
#   -1.78502031e+02  1.39950000e+04]
#  [ 1.40100000e+04  1.42300000e+04  1.42300000e+04  1.39600000e+04
#    1.52096570e+07 -6.78309905e+01 -1.10567389e+01 -5.67742516e+01
#   -1.34531412e+02  1.41100000e+04]]

# %%
y= data[0:, 0]
print (y.shape)
X= data[:3429,:]
print (X.shape)
y
# Out:
# (3429,)
# (3429, 10)
# array([14670., 14840., 14810., ...,  2365.,  2365.,  2365.])

# %%
X
# Out:
# array([[ 1.46700000e+04,  1.49000000e+04,  1.49000000e+04, ...,
#          1.19658120e+00,  6.66666667e+01,  1.47000000e+04],
#        [ 1.48400000e+04,  1.47400000e+04,  1.50000000e+04, ...,
#          4.25301505e+00,  9.34210526e+01,  1.48200000e+04],
#        [ 1.48100000e+04,  1.50500000e+04,  1.50500000e+04, ...,
#          3.76251630e+00,  6.75990676e+01,  1.48950000e+04],
#        ...,
#        [ 2.36500000e+03,  2.31800000e+03,  2.36500000e+03, ...,
#         -1.51551850e+01, -3.58974359e+01,  2.31800000e+03],
#        [ 2.36500000e+03,  2.31800000e+03,  2.36500000e+03, ...,
#         -1.61802001e+01, -3.58974359e+01,  2.31800000e+03],
#        [ 2.36500000e+03,  2.31800000e+03,  2.36500000e+03, ...,
#         -1.68977792e+01, -3.58974359e+01,  2.31800000e+03]])

# %%
y= (y- min(y))/(max(y)- min(y))
print (y[3423:])
print (y[:7])
# Out:
# [0.05528036 0.05528036 0.05528036 0.05528036 0.05528036 0.05528036]
# [0.56749781 0.57457437 0.57332556 0.5729093  0.58081838 0.58747867
#  0.58747867]

# %%
print(np.min(X,axis=0))
# Out:
# [ 1037.             0.             0.             0.
#      0.         -1867.19289514 -1739.09465093  -814.79697056
#   -466.66666667     0.        ]

# %%
X= (X- np.min(X,axis=0))/(np.max(X, axis=0)-np.min(X,axis=0))
#X= (X- np.min(X))/(np.max(X)-np.min(X))
print (X.shape)
print (X[:3, :])
# Out:
# (3429, 10)
# [[0.56749781 0.57285659 0.57285659 0.58797417 0.00248242 0.47655597
#   0.51724898 0.5400412  0.57142857 0.57885411]
#  [0.57457437 0.56670511 0.57670127 0.59483454 0.00618817 0.47808765
#   0.51812666 0.54206401 0.60009398 0.58357944]
#  [0.57332556 0.57862361 0.57862361 0.59443099 0.00428025 0.47845389
#   0.51869946 0.54173939 0.57242757 0.58653278]]

# %%
time_steps= 100
X_new= np.zeros((X.shape[0] - time_steps +1, 100, X.shape[1]))
y_new= np.zeros((y.shape[0] -time_steps +1,))
for ix in range(X_new.shape[0]):
    for jx in range(time_steps):
        X_new[ix, jx, :]= X[ix +jx, :]
    y_new[ix]= y[ix + time_steps -1]
print (X_new.shape, y_new.shape)
# Out:
# (3330, 100, 10) (3330,)

# %%
split = int(0.90*data.shape[0])
X_train = X_new[:split]
X_test = X_new[split:]

y_train = y_new[:split]
y_test = y_new[split:]

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (3086, 100, 10) (3086,)
# (244, 100, 10) (244,)

# %%
model = Sequential()
model.add(Convolution1D(64, 3, padding='same',input_shape= (100,10)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.2))
model.add(Convolution1D(32, 3, padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(units=1))
model.add(Activation('linear'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 100, 64)           1984
#
#  max_pooling1d_2 (MaxPooling  (None, 50, 64)           0
#  1D)
#
#  lstm_1 (LSTM)               (None, 50, 100)           66000
#
#  dropout_1 (Dropout)         (None, 50, 100)           0
#
#  conv1d_3 (Conv1D)           (None, 50, 32)            9632
#
#  max_pooling1d_3 (MaxPooling  (None, 25, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 800)               0
#
#  dense_1 (Dense)             (None, 1)                 801
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 78,417
# Trainable params: 78,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=256, epochs=70, validation_data = (X_test, y_test), verbose=2)
# Out:
# Epoch 1/70
# 13/13 - 3s - loss: 0.0150 - accuracy: 0.0013 - val_loss: 4.5354e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 259ms/step
# Epoch 2/70
# 13/13 - 2s - loss: 0.0047 - accuracy: 0.0013 - val_loss: 0.0023 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 3/70
# 13/13 - 2s - loss: 0.0025 - accuracy: 0.0013 - val_loss: 6.6816e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 4/70
# 13/13 - 2s - loss: 0.0020 - accuracy: 0.0013 - val_loss: 6.5800e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 5/70
# 13/13 - 2s - loss: 0.0021 - accuracy: 0.0013 - val_loss: 3.3394e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 125ms/step
# Epoch 6/70
# 13/13 - 2s - loss: 0.0018 - accuracy: 0.0013 - val_loss: 4.4953e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 7/70
# 13/13 - 2s - loss: 0.0019 - accuracy: 0.0013 - val_loss: 8.4461e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 8/70
# 13/13 - 2s - loss: 0.0015 - accuracy: 0.0013 - val_loss: 3.2286e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 9/70
# 13/13 - 2s - loss: 0.0013 - accuracy: 0.0013 - val_loss: 4.5869e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 120ms/step
# Epoch 10/70
# 13/13 - 2s - loss: 0.0013 - accuracy: 0.0013 - val_loss: 4.8999e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 11/70
# 13/13 - 2s - loss: 0.0011 - accuracy: 0.0013 - val_loss: 3.5779e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 12/70
# 13/13 - 2s - loss: 0.0011 - accuracy: 0.0013 - val_loss: 2.2045e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 13/70
# 13/13 - 2s - loss: 9.3517e-04 - accuracy: 0.0013 - val_loss: 4.1689e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 120ms/step
# Epoch 14/70
# 13/13 - 2s - loss: 9.5093e-04 - accuracy: 0.0013 - val_loss: 2.8524e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 122ms/step
# Epoch 15/70
# 13/13 - 2s - loss: 8.5201e-04 - accuracy: 0.0013 - val_loss: 2.1771e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 124ms/step
# Epoch 16/70
# 13/13 - 2s - loss: 9.2689e-04 - accuracy: 0.0013 - val_loss: 4.2872e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 122ms/step
# Epoch 17/70
# 13/13 - 2s - loss: 8.2085e-04 - accuracy: 0.0013 - val_loss: 4.0283e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 120ms/step
# Epoch 18/70
# 13/13 - 2s - loss: 8.9678e-04 - accuracy: 0.0013 - val_loss: 1.3087e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 19/70
# 13/13 - 2s - loss: 7.4261e-04 - accuracy: 0.0013 - val_loss: 1.8943e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 20/70
# 13/13 - 2s - loss: 7.0756e-04 - accuracy: 0.0013 - val_loss: 4.0636e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 120ms/step
# Epoch 21/70
# 13/13 - 2s - loss: 7.5578e-04 - accuracy: 0.0013 - val_loss: 1.6066e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 22/70
# 13/13 - 2s - loss: 6.6986e-04 - accuracy: 0.0013 - val_loss: 1.3332e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 23/70
# 13/13 - 2s - loss: 6.2102e-04 - accuracy: 0.0013 - val_loss: 1.4828e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 24/70
# 13/13 - 2s - loss: 6.2364e-04 - accuracy: 0.0013 - val_loss: 1.5378e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 25/70
# 13/13 - 2s - loss: 5.3668e-04 - accuracy: 0.0013 - val_loss: 1.5377e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 121ms/step
# Epoch 26/70
# 13/13 - 2s - loss: 6.1666e-04 - accuracy: 0.0013 - val_loss: 1.1942e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 27/70
# 13/13 - 2s - loss: 5.8604e-04 - accuracy: 0.0013 - val_loss: 1.5175e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 28/70
# 13/13 - 2s - loss: 9.8851e-04 - accuracy: 0.0013 - val_loss: 3.9960e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 29/70
# 13/13 - 2s - loss: 0.0011 - accuracy: 0.0013 - val_loss: 7.4343e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 30/70
# 13/13 - 2s - loss: 5.8079e-04 - accuracy: 0.0013 - val_loss: 1.9076e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 31/70
# 13/13 - 2s - loss: 4.8077e-04 - accuracy: 0.0013 - val_loss: 1.7829e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 32/70
# 13/13 - 2s - loss: 4.6791e-04 - accuracy: 0.0013 - val_loss: 1.5720e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 33/70
# 13/13 - 2s - loss: 4.1965e-04 - accuracy: 0.0013 - val_loss: 2.1926e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 34/70
# 13/13 - 2s - loss: 4.1229e-04 - accuracy: 0.0013 - val_loss: 1.2500e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 35/70
# 13/13 - 2s - loss: 4.7667e-04 - accuracy: 0.0013 - val_loss: 2.8705e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 36/70
# 13/13 - 2s - loss: 4.0288e-04 - accuracy: 0.0013 - val_loss: 3.1441e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 37/70
# 13/13 - 2s - loss: 4.1807e-04 - accuracy: 0.0013 - val_loss: 4.4056e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 38/70
# 13/13 - 2s - loss: 3.9043e-04 - accuracy: 0.0013 - val_loss: 2.7924e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 125ms/step
# Epoch 39/70
# 13/13 - 2s - loss: 3.3908e-04 - accuracy: 0.0013 - val_loss: 4.4143e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 40/70
# 13/13 - 2s - loss: 5.2168e-04 - accuracy: 0.0013 - val_loss: 1.4649e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 41/70
# 13/13 - 2s - loss: 5.7478e-04 - accuracy: 0.0013 - val_loss: 1.3606e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 123ms/step
# Epoch 42/70
# 13/13 - 2s - loss: 3.7809e-04 - accuracy: 0.0013 - val_loss: 1.7456e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 123ms/step
# Epoch 43/70
# 13/13 - 2s - loss: 3.8329e-04 - accuracy: 0.0013 - val_loss: 2.4665e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 124ms/step
# Epoch 44/70
# 13/13 - 2s - loss: 3.3659e-04 - accuracy: 0.0013 - val_loss: 1.9843e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 122ms/step
# Epoch 45/70
# 13/13 - 2s - loss: 3.1066e-04 - accuracy: 0.0013 - val_loss: 3.1206e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 46/70
# 13/13 - 2s - loss: 3.2150e-04 - accuracy: 0.0013 - val_loss: 2.6078e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 47/70
# 13/13 - 2s - loss: 2.9420e-04 - accuracy: 0.0013 - val_loss: 2.4934e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 48/70
# 13/13 - 1s - loss: 3.0850e-04 - accuracy: 0.0013 - val_loss: 1.6952e-04 - val_accuracy: 0.0000e+00 - 1s/epoch - 115ms/step
# Epoch 49/70
# 13/13 - 2s - loss: 2.9476e-04 - accuracy: 0.0013 - val_loss: 1.2004e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 50/70
# 13/13 - 2s - loss: 2.7070e-04 - accuracy: 0.0013 - val_loss: 1.3502e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 120ms/step
# Epoch 51/70
# 13/13 - 2s - loss: 2.4913e-04 - accuracy: 0.0013 - val_loss: 2.6696e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 52/70
# 13/13 - 2s - loss: 2.9398e-04 - accuracy: 0.0013 - val_loss: 1.5589e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 121ms/step
# Epoch 53/70
# 13/13 - 2s - loss: 2.5922e-04 - accuracy: 0.0013 - val_loss: 2.3761e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 54/70
# 13/13 - 2s - loss: 3.5357e-04 - accuracy: 0.0013 - val_loss: 2.2680e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 55/70
# 13/13 - 2s - loss: 2.8059e-04 - accuracy: 0.0013 - val_loss: 1.2601e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 56/70
# 13/13 - 2s - loss: 2.4515e-04 - accuracy: 0.0013 - val_loss: 1.7553e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 57/70
# 13/13 - 2s - loss: 2.4161e-04 - accuracy: 0.0013 - val_loss: 8.2368e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 58/70
# 13/13 - 2s - loss: 2.5188e-04 - accuracy: 0.0013 - val_loss: 9.9590e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 59/70
# 13/13 - 2s - loss: 2.4336e-04 - accuracy: 0.0013 - val_loss: 1.4377e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 115ms/step
# Epoch 60/70
# 13/13 - 2s - loss: 2.4099e-04 - accuracy: 0.0013 - val_loss: 9.1981e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step
# Epoch 61/70
# 13/13 - 2s - loss: 2.1176e-04 - accuracy: 0.0013 - val_loss: 1.2596e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 62/70
# 13/13 - 2s - loss: 2.0419e-04 - accuracy: 0.0013 - val_loss: 1.2553e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 63/70
# 13/13 - 2s - loss: 1.9081e-04 - accuracy: 0.0013 - val_loss: 1.3299e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 123ms/step
# Epoch 64/70
# 13/13 - 2s - loss: 2.3322e-04 - accuracy: 0.0013 - val_loss: 1.0511e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 120ms/step
# Epoch 65/70
# 13/13 - 2s - loss: 2.2152e-04 - accuracy: 0.0013 - val_loss: 7.2082e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 66/70
# 13/13 - 2s - loss: 2.0249e-04 - accuracy: 0.0013 - val_loss: 1.3157e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 67/70
# 13/13 - 2s - loss: 2.0422e-04 - accuracy: 0.0013 - val_loss: 1.4416e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 117ms/step
# Epoch 68/70
# 13/13 - 2s - loss: 1.8706e-04 - accuracy: 0.0013 - val_loss: 6.2198e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 116ms/step
# Epoch 69/70
# 13/13 - 2s - loss: 1.8834e-04 - accuracy: 0.0013 - val_loss: 8.4779e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 118ms/step
# Epoch 70/70
# 13/13 - 2s - loss: 2.0557e-04 - accuracy: 0.0013 - val_loss: 8.0246e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 119ms/step

# %%
score= model.evaluate(X_test, y_test, batch_size=256)
# Out:
# 1/1 [==============================] - 0s 54ms/step - loss: 8.0246e-05 - accuracy: 0.0000e+00

# %%
print (score)
# Out:
# [8.024580893106759e-05, 0.0]

# %%
y_pred= model.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 9ms/step

# %%
plt.plot(y_pred, 'r-')
plt.plot(y_test, 'b-')
plt.show()

# %%
import math

# %%
MSE = np.square(np.subtract(y_test,y_pred)).mean() 
print (MSE)
# Out:
# 0.000372971272309287

# %%
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 0.01931246416978649

# %%
def mae(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs(y_test - y_pred))
print(mae(y_test, y_pred))
# Out:
# 0.015088846305677289

# %%
plt.plot (y_pred, y_test, 'bo')
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.show()
