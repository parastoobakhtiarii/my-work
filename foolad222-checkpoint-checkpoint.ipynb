# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel (r'C:\Users\Parastoo\OneDrive\Desktop\fooladtest2.xlsx')

# %%
data
# Out:
#           date  Close   Open   High    Low    Volume
# 0     20220622  11440  11460  11550  11310  43038062
# 1     20220621  11550  11580  11610  11460  42656631
# 2     20220620  11620  11590  11740  11580  49782910
# 3     20220619  11610  11660  11740  11560  45368856
# 4     20220618  11610  11650  11750  11550  60658889
# ...        ...    ...    ...    ...    ...       ...
# 3532  20070627   2061   2070   2070   2052   4943752
# 3533  20070626   2093   2137   2137   2065   9614186
# 3534  20070625   2096   2065   2097   2062  10909057
# 3535  20070624   2056   2030   2068   2026   7875528
# 3536  20070623   2028   2000   2030   1995   9940077
#
# [3537 rows x 6 columns]

# %%
data= data.dropna(axis=0)
data.tail()
# Out:
#           date  Close  Open  High   Low    Volume
# 3532  20070627   2061  2070  2070  2052   4943752
# 3533  20070626   2093  2137  2137  2065   9614186
# 3534  20070625   2096  2065  2097  2062  10909057
# 3535  20070624   2056  2030  2068  2026   7875528
# 3536  20070623   2028  2000  2030  1995   9940077

# %%
from stockstats import StockDataFrame as Sdf

# %%
stock = Sdf.retype(data)

# %%
data['macd']=stock['macd']
data.sort_values(by=['date'], inplace=True, ascending=False)
data
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220622  11440  11460  11550  11310  43038062    0.000000    0.000000
# 20220621  11550  11580  11610  11460  42656631    2.467949    1.371083
# 20220620  11620  11590  11740  11580  49782910    5.315352    2.987587
# 20220619  11610  11660  11740  11560  45368856    6.119095    4.048396
# 20220618  11610  11650  11750  11550  60658889    6.427015    4.755981
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070627   2061   2070   2070   2052   4943752 -164.151395 -154.689735
# 20070626   2093   2137   2137   2065   9614186 -162.520115 -156.255811
# 20070625   2096   2065   2097   2062  10909057 -159.150649 -156.834778
# 20070624   2056   2030   2068   2026   7875528 -157.887954 -157.045413
# 20070623   2028   2000   2030   1995   9940077 -157.332989 -157.102929
#
#              macdh
# date
# 20220622  0.000000
# 20220621  1.096866
# 20220620  2.327766
# 20220619  2.070700
# 20220618  1.671034
# ...            ...
# 20070627 -9.461660
# 20070626 -6.264304
# 20070625 -2.315870
# 20070624 -0.842541
# 20070623 -0.230060
#
# [3537 rows x 8 columns]

# %%
data['rsi']=stock['rsi']
#data['rsi']=stock['rsi_14']

# %%
data
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220622  11440  11460  11550  11310  43038062    0.000000    0.000000
# 20220621  11550  11580  11610  11460  42656631    2.467949    1.371083
# 20220620  11620  11590  11740  11580  49782910    5.315352    2.987587
# 20220619  11610  11660  11740  11560  45368856    6.119095    4.048396
# 20220618  11610  11650  11750  11550  60658889    6.427015    4.755981
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070627   2061   2070   2070   2052   4943752 -164.151395 -154.689735
# 20070626   2093   2137   2137   2065   9614186 -162.520115 -156.255811
# 20070625   2096   2065   2097   2062  10909057 -159.150649 -156.834778
# 20070624   2056   2030   2068   2026   7875528 -157.887954 -157.045413
# 20070623   2028   2000   2030   1995   9940077 -157.332989 -157.102929
#
#              macdh         rsi
# date
# 20220622  0.000000         NaN
# 20220621  1.096866  100.000000
# 20220620  2.327766  100.000000
# 20220619  2.070700   94.112346
# 20220618  1.671034   94.112346
# ...            ...         ...
# 20070627 -9.461660    6.042103
# 20070626 -6.264304   13.250048
# 20070625 -2.315870   13.916782
# 20070624 -0.842541   12.533591
# 20070623 -0.230060   11.659969
#
# [3537 rows x 9 columns]

# %%
data['CCI']=stock['cci']
#data['STCK%']=stock['kdjk']
#data['ADO'] = (data['high'] - data['close'])/(data['high']-data['low'])

# %%
data
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220622  11440  11460  11550  11310  43038062    0.000000    0.000000
# 20220621  11550  11580  11610  11460  42656631    2.467949    1.371083
# 20220620  11620  11590  11740  11580  49782910    5.315352    2.987587
# 20220619  11610  11660  11740  11560  45368856    6.119095    4.048396
# 20220618  11610  11650  11750  11550  60658889    6.427015    4.755981
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070627   2061   2070   2070   2052   4943752 -164.151395 -154.689735
# 20070626   2093   2137   2137   2065   9614186 -162.520115 -156.255811
# 20070625   2096   2065   2097   2062  10909057 -159.150649 -156.834778
# 20070624   2056   2030   2068   2026   7875528 -157.887954 -157.045413
# 20070623   2028   2000   2030   1995   9940077 -157.332989 -157.102929
#
#              macdh         rsi         CCI
# date
# 20220622  0.000000         NaN         NaN
# 20220621  1.096866  100.000000   66.666667
# 20220620  2.327766  100.000000  100.000000
# 20220619  2.070700   94.112346   62.365591
# 20220618  1.671034   94.112346   52.536232
# ...            ...         ...         ...
# 20070627 -9.461660    6.042103 -101.113347
# 20070626 -6.264304   13.250048  -70.013029
# 20070625 -2.315870   13.916782  -68.212645
# 20070624 -0.842541   12.533591  -79.321499
# 20070623 -0.230060   11.659969  -91.087344
#
# [3537 rows x 10 columns]

# %%
#data['wr_12']=stock['wr_12']

# %%
data['open_2_sma'] = stock['open_2_sma']
data
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220622  11440  11460  11550  11310  43038062    0.000000    0.000000
# 20220621  11550  11580  11610  11460  42656631    2.467949    1.371083
# 20220620  11620  11590  11740  11580  49782910    5.315352    2.987587
# 20220619  11610  11660  11740  11560  45368856    6.119095    4.048396
# 20220618  11610  11650  11750  11550  60658889    6.427015    4.755981
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070627   2061   2070   2070   2052   4943752 -164.151395 -154.689735
# 20070626   2093   2137   2137   2065   9614186 -162.520115 -156.255811
# 20070625   2096   2065   2097   2062  10909057 -159.150649 -156.834778
# 20070624   2056   2030   2068   2026   7875528 -157.887954 -157.045413
# 20070623   2028   2000   2030   1995   9940077 -157.332989 -157.102929
#
#              macdh         rsi         CCI  open_2_sma
# date
# 20220622  0.000000         NaN         NaN     11460.0
# 20220621  1.096866  100.000000   66.666667     11520.0
# 20220620  2.327766  100.000000  100.000000     11585.0
# 20220619  2.070700   94.112346   62.365591     11625.0
# 20220618  1.671034   94.112346   52.536232     11655.0
# ...            ...         ...         ...         ...
# 20070627 -9.461660    6.042103 -101.113347      2085.0
# 20070626 -6.264304   13.250048  -70.013029      2103.5
# 20070625 -2.315870   13.916782  -68.212645      2101.0
# 20070624 -0.842541   12.533591  -79.321499      2047.5
# 20070623 -0.230060   11.659969  -91.087344      2015.0
#
# [3537 rows x 11 columns]

# %%
data.replace([np.inf, -np.inf], np.nan)
data.dropna()
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220621  11550  11580  11610  11460  42656631    2.467949    1.371083
# 20220620  11620  11590  11740  11580  49782910    5.315352    2.987587
# 20220619  11610  11660  11740  11560  45368856    6.119095    4.048396
# 20220618  11610  11650  11750  11550  60658889    6.427015    4.755981
# 20220615  11710  11730  11990  11580  38764404   10.767368    6.385401
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070627   2061   2070   2070   2052   4943752 -164.151395 -154.689735
# 20070626   2093   2137   2137   2065   9614186 -162.520115 -156.255811
# 20070625   2096   2065   2097   2062  10909057 -159.150649 -156.834778
# 20070624   2056   2030   2068   2026   7875528 -157.887954 -157.045413
# 20070623   2028   2000   2030   1995   9940077 -157.332989 -157.102929
#
#              macdh         rsi         CCI  open_2_sma
# date
# 20220621  1.096866  100.000000   66.666667     11520.0
# 20220620  2.327766  100.000000  100.000000     11585.0
# 20220619  2.070700   94.112346   62.365591     11625.0
# 20220618  1.671034   94.112346   52.536232     11655.0
# 20220615  4.381967   96.501335  123.636364     11690.0
# ...            ...         ...         ...         ...
# 20070627 -9.461660    6.042103 -101.113347      2085.0
# 20070626 -6.264304   13.250048  -70.013029      2103.5
# 20070625 -2.315870   13.916782  -68.212645      2101.0
# 20070624 -0.842541   12.533591  -79.321499      2047.5
# 20070623 -0.230060   11.659969  -91.087344      2015.0
#
# [3517 rows x 11 columns]

# %%
data.isnull().any()
# Out:
# close         False
# open          False
# high          False
# low           False
# volume        False
# macd          False
# macds         False
# macdh         False
# rsi            True
# CCI            True
# open_2_sma    False
# dtype: bool

# %%
#Drop rows with NaN values
#data['open'].dropna()
data.describe()
data = data.dropna(subset=['open'])
data = data.dropna(subset=['high'])
data = data.dropna(subset=['low'])
data = data.dropna(subset=['close'])
#data = data.dropna(subset=['adj close*'])
data = data.dropna(subset=['volume'])
data = data.dropna(subset=['macd'])
data = data.dropna(subset=['macds'])
data = data.dropna(subset=['macdh'])
data = data.dropna(subset=['rsi'])
#data = data.dropna(subset=['wr_12'])
data = data.dropna(subset=['open_2_sma'])
data = data.dropna(subset=['CCI'])
#data = data.dropna(subset=['ADO'])
data.isnull().any()
# Out:
# close         False
# open          False
# high          False
# low           False
# volume        False
# macd          False
# macds         False
# macdh         False
# rsi           False
# CCI           False
# open_2_sma    False
# dtype: bool

# %%
data= data.dropna(axis=0)
data= data.dropna(axis=1)
data.tail()
# Out:
#           close  open  high   low    volume        macd       macds     macdh  \
# date
# 20070627   2061  2070  2070  2052   4943752 -164.151395 -154.689735 -9.461660
# 20070626   2093  2137  2137  2065   9614186 -162.520115 -156.255811 -6.264304
# 20070625   2096  2065  2097  2062  10909057 -159.150649 -156.834778 -2.315870
# 20070624   2056  2030  2068  2026   7875528 -157.887954 -157.045413 -0.842541
# 20070623   2028  2000  2030  1995   9940077 -157.332989 -157.102929 -0.230060
#
#                 rsi         CCI  open_2_sma
# date
# 20070627   6.042103 -101.113347      2085.0
# 20070626  13.250048  -70.013029      2103.5
# 20070625  13.916782  -68.212645      2101.0
# 20070624  12.533591  -79.321499      2047.5
# 20070623  11.659969  -91.087344      2015.0

# %%
data.sort_values(by=['date'], inplace=True, ascending=False)
data
# Out:
#           close   open   high    low    volume        macd       macds  \
# date
# 20220621  11550  11580  11610  11460  42656631    2.467949    1.371083
# 20220620  11620  11590  11740  11580  49782910    5.315352    2.987587
# 20220619  11610  11660  11740  11560  45368856    6.119095    4.048396
# 20220618  11610  11650  11750  11550  60658889    6.427015    4.755981
# 20220615  11710  11730  11990  11580  38764404   10.767368    6.385401
# ...         ...    ...    ...    ...       ...         ...         ...
# 20070627   2061   2070   2070   2052   4943752 -164.151395 -154.689735
# 20070626   2093   2137   2137   2065   9614186 -162.520115 -156.255811
# 20070625   2096   2065   2097   2062  10909057 -159.150649 -156.834778
# 20070624   2056   2030   2068   2026   7875528 -157.887954 -157.045413
# 20070623   2028   2000   2030   1995   9940077 -157.332989 -157.102929
#
#              macdh         rsi         CCI  open_2_sma
# date
# 20220621  1.096866  100.000000   66.666667     11520.0
# 20220620  2.327766  100.000000  100.000000     11585.0
# 20220619  2.070700   94.112346   62.365591     11625.0
# 20220618  1.671034   94.112346   52.536232     11655.0
# 20220615  4.381967   96.501335  123.636364     11690.0
# ...            ...         ...         ...         ...
# 20070627 -9.461660    6.042103 -101.113347      2085.0
# 20070626 -6.264304   13.250048  -70.013029      2103.5
# 20070625 -2.315870   13.916782  -68.212645      2101.0
# 20070624 -0.842541   12.533591  -79.321499      2047.5
# 20070623 -0.230060   11.659969  -91.087344      2015.0
#
# [3517 rows x 11 columns]

# %%
#data.columns = [ 'high', 'low' ,'open' , 'macd' , 'macds' , 'macdh' , 'rsi'  , 'CCI'  , 'ADO' , 'open_sma' , 'wr_12', 'close' , 'volume'  ]
#data

# %%
from keras.layers import Dense, Dropout, Activation, LSTM, Convolution1D, MaxPooling1D, Flatten
from keras.models import Sequential

# %%
data= data.values[:, 0:11]
print (data.shape)
# Out:
# (3517, 11)

# %%
print (data[:11, :])
# Out:
# [[ 1.15500000e+04  1.15800000e+04  1.16100000e+04  1.14600000e+04
#    4.26566310e+07  2.46794872e+00  1.37108262e+00  1.09686610e+00
#    1.00000000e+02  6.66666667e+01  1.15200000e+04]
#  [ 1.16200000e+04  1.15900000e+04  1.17400000e+04  1.15800000e+04
#    4.97829100e+07  5.31535233e+00  2.98758660e+00  2.32776573e+00
#    1.00000000e+02  1.00000000e+02  1.15850000e+04]
#  [ 1.16100000e+04  1.16600000e+04  1.17400000e+04  1.15600000e+04
#    4.53688560e+07  6.11909534e+00  4.04839579e+00  2.07069954e+00
#    9.41123460e+01  6.23655914e+01  1.16250000e+04]
#  [ 1.16100000e+04  1.16500000e+04  1.17500000e+04  1.15500000e+04
#    6.06588890e+07  6.42701490e+00  4.75598120e+00  1.67103370e+00
#    9.41123460e+01  5.25362319e+01  1.16550000e+04]
#  [ 1.17100000e+04  1.17300000e+04  1.19900000e+04  1.15800000e+04
#    3.87644040e+07  1.07673684e+01  6.38540135e+00  4.38196701e+00
#    9.65013346e+01  1.23636364e+02  1.16900000e+04]
#  [ 1.18200000e+04  1.17500000e+04  1.19100000e+04  1.16400000e+04
#    6.69112380e+07  1.83486005e+01  9.41296790e+00  8.93563260e+00
#    9.76371103e+01  1.22293676e+02  1.17400000e+04]
#  [ 1.18200000e+04  1.16000000e+04  1.21000000e+04  1.16000000e+04
#    1.06858966e+08  2.31370283e+01  1.27111177e+01  1.04259106e+01
#    9.76371103e+01  1.17159361e+02  1.16750000e+04]
#  [ 1.14600000e+04  1.13000000e+04  1.17000000e+04  1.12000000e+04
#    7.13785410e+07  8.23997431e+00  1.16782614e+01 -3.43828708e+00
#    4.37409640e+01 -1.13384030e+02  1.14500000e+04]
#  [ 1.12900000e+04  1.12600000e+04  1.13400000e+04  1.11500000e+04
#    6.08881120e+07 -1.12040669e+01  6.55129155e+00 -1.77553584e+01
#    3.41534074e+01 -1.59019975e+02  1.12800000e+04]
#  [ 1.12900000e+04  1.13600000e+04  1.13600000e+04  1.12500000e+04
#    5.04489120e+07 -2.50975117e+01 -3.73285768e-01 -2.47242260e+01
#    3.41534074e+01 -1.14099458e+02  1.13100000e+04]
#  [ 1.12800000e+04  1.13400000e+04  1.13400000e+04  1.11500000e+04
#    7.95722070e+07 -3.54913523e+01 -7.91517366e+00 -2.75761786e+01
#    3.36502221e+01 -1.12043011e+02  1.13500000e+04]]

# %%
y= data[0:, 0]
print (y.shape)
X= data[:3517,:]
print (X.shape)
y
# Out:
# (3517,)
# (3517, 11)
# array([11550., 11620., 11610., ...,  2096.,  2056.,  2028.])

# %%
X
# Out:
# array([[ 1.15500000e+04,  1.15800000e+04,  1.16100000e+04, ...,
#          1.00000000e+02,  6.66666667e+01,  1.15200000e+04],
#        [ 1.16200000e+04,  1.15900000e+04,  1.17400000e+04, ...,
#          1.00000000e+02,  1.00000000e+02,  1.15850000e+04],
#        [ 1.16100000e+04,  1.16600000e+04,  1.17400000e+04, ...,
#          9.41123460e+01,  6.23655914e+01,  1.16250000e+04],
#        ...,
#        [ 2.09600000e+03,  2.06500000e+03,  2.09700000e+03, ...,
#          1.39167824e+01, -6.82126449e+01,  2.10100000e+03],
#        [ 2.05600000e+03,  2.03000000e+03,  2.06800000e+03, ...,
#          1.25335908e+01, -7.93214990e+01,  2.04750000e+03],
#        [ 2.02800000e+03,  2.00000000e+03,  2.03000000e+03, ...,
#          1.16599688e+01, -9.10873440e+01,  2.01500000e+03]])

# %%
y= (y- min(y))/(max(y)- min(y))
print (y[3510:])
print (y[:7])
# Out:
# [0.05039975 0.04858872 0.04682186 0.04823535 0.04836786 0.046601
#  0.04536419]
# [0.46596581 0.46905782 0.4686161  0.4686161  0.47303326 0.47789213
#  0.47789213]

# %%
print(np.min(X,axis=0))
# Out:
# [ 1.00100000e+03  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -2.22996710e+03 -2.17367364e+03 -7.93449117e+02
#   1.69731994e+00 -4.66666667e+02  0.00000000e+00]

# %%
X= (X- np.min(X,axis=0))/(np.max(X, axis=0)-np.min(X,axis=0))
#X= (X- np.min(X))/(np.max(X)-np.min(X))
print (X.shape)
print (X[:3, :])
# Out:
# (3517, 11)
# [[0.46596581 0.49487179 0.46776793 0.50043668 0.03946158 0.60619946
#   0.61834168 0.58277143 1.         0.57142857 0.4944206 ]
#  [0.46905782 0.49529915 0.47300564 0.50567686 0.04605409 0.60697265
#   0.61880124 0.58367425 1.         0.60714286 0.4972103 ]
#  [0.4686161  0.4982906  0.47300564 0.50480349 0.04197066 0.6071909
#   0.61910282 0.5834857  0.94010688 0.56682028 0.49892704]]

# %%
time_steps= 50
X_new= np.zeros((X.shape[0] - time_steps +1, 100, X.shape[1]))
y_new= np.zeros((y.shape[0] -time_steps +1,))
for ix in range(X_new.shape[0]):
    for jx in range(time_steps):
        X_new[ix, jx, :]= X[ix +jx, :]
    y_new[ix]= y[ix + time_steps -1]
print (X_new.shape, y_new.shape)
# Out:
# (3468, 100, 11) (3468,)

# %%
split = int(0.80*data.shape[0])
X_train = X_new[:split]
X_test = X_new[split:]

y_train = y_new[:split]
y_test = y_new[split:]

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (2813, 100, 11) (2813,)
# (655, 100, 11) (655,)

# %%
model = Sequential()
model.add(Convolution1D(64, 3, padding='same',input_shape= (100,11)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.2))
model.add(Convolution1D(32, 3, padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(units=1))
model.add(Activation('linear'))

model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_30 (Conv1D)          (None, 100, 64)           2176
#
#  max_pooling1d_30 (MaxPoolin  (None, 50, 64)           0
#  g1D)
#
#  lstm_15 (LSTM)              (None, 50, 100)           66000
#
#  dropout_15 (Dropout)        (None, 50, 100)           0
#
#  conv1d_31 (Conv1D)          (None, 50, 32)            9632
#
#  max_pooling1d_31 (MaxPoolin  (None, 25, 32)           0
#  g1D)
#
#  flatten_15 (Flatten)        (None, 800)               0
#
#  dense_15 (Dense)            (None, 1)                 801
#
#  activation_15 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 78,609
# Trainable params: 78,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=128, epochs=70, validation_data = (X_test, y_test), verbose=2)
# Out:
# Epoch 1/70
# 22/22 - 4s - loss: 0.0127 - accuracy: 7.1098e-04 - val_loss: 9.2681e-04 - val_accuracy: 0.0000e+00 - 4s/epoch - 198ms/step
# Epoch 2/70
# 22/22 - 2s - loss: 0.0029 - accuracy: 7.1098e-04 - val_loss: 3.2951e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 113ms/step
# Epoch 3/70
# 22/22 - 3s - loss: 0.0022 - accuracy: 7.1098e-04 - val_loss: 2.6244e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 115ms/step
# Epoch 4/70
# 22/22 - 3s - loss: 0.0016 - accuracy: 7.1098e-04 - val_loss: 2.9498e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 116ms/step
# Epoch 5/70
# 22/22 - 3s - loss: 0.0013 - accuracy: 7.1098e-04 - val_loss: 2.4290e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 118ms/step
# Epoch 6/70
# 22/22 - 3s - loss: 0.0011 - accuracy: 7.1098e-04 - val_loss: 2.9977e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 117ms/step
# Epoch 7/70
# 22/22 - 3s - loss: 0.0010 - accuracy: 7.1098e-04 - val_loss: 1.7298e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 118ms/step
# Epoch 8/70
# 22/22 - 3s - loss: 8.3248e-04 - accuracy: 7.1098e-04 - val_loss: 1.4207e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 117ms/step
# Epoch 9/70
# 22/22 - 3s - loss: 7.2264e-04 - accuracy: 7.1098e-04 - val_loss: 1.8115e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 117ms/step
# Epoch 10/70
# 22/22 - 3s - loss: 6.8970e-04 - accuracy: 7.1098e-04 - val_loss: 1.3815e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 118ms/step
# Epoch 11/70
# 22/22 - 3s - loss: 6.3065e-04 - accuracy: 7.1098e-04 - val_loss: 2.7815e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 118ms/step
# Epoch 12/70
# 22/22 - 3s - loss: 5.9511e-04 - accuracy: 7.1098e-04 - val_loss: 1.7741e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 118ms/step
# Epoch 13/70
# 22/22 - 3s - loss: 5.4349e-04 - accuracy: 7.1098e-04 - val_loss: 1.8542e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 116ms/step
# Epoch 14/70
# 22/22 - 3s - loss: 4.9145e-04 - accuracy: 7.1098e-04 - val_loss: 2.3832e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 116ms/step
# Epoch 15/70
# 22/22 - 3s - loss: 4.5239e-04 - accuracy: 7.1098e-04 - val_loss: 1.2658e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 117ms/step
# Epoch 16/70
# 22/22 - 3s - loss: 4.1792e-04 - accuracy: 7.1098e-04 - val_loss: 1.2226e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 117ms/step
# Epoch 17/70
# 22/22 - 3s - loss: 4.1238e-04 - accuracy: 7.1098e-04 - val_loss: 1.2732e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 117ms/step
# Epoch 18/70
# 22/22 - 3s - loss: 3.3869e-04 - accuracy: 7.1098e-04 - val_loss: 1.6965e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 117ms/step
# Epoch 19/70
# 22/22 - 3s - loss: 3.7927e-04 - accuracy: 7.1098e-04 - val_loss: 9.9538e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 119ms/step
# Epoch 20/70
# 22/22 - 3s - loss: 4.0457e-04 - accuracy: 7.1098e-04 - val_loss: 2.7917e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 118ms/step
# Epoch 21/70
# 22/22 - 3s - loss: 3.8518e-04 - accuracy: 7.1098e-04 - val_loss: 8.4069e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 118ms/step
# Epoch 22/70
# 22/22 - 3s - loss: 3.8195e-04 - accuracy: 7.1098e-04 - val_loss: 3.2194e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 119ms/step
# Epoch 23/70
# 22/22 - 3s - loss: 3.4783e-04 - accuracy: 7.1098e-04 - val_loss: 1.8236e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 120ms/step
# Epoch 24/70
# 22/22 - 3s - loss: 2.9679e-04 - accuracy: 7.1098e-04 - val_loss: 1.0183e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 121ms/step
# Epoch 25/70
# 22/22 - 3s - loss: 3.3223e-04 - accuracy: 7.1098e-04 - val_loss: 1.7289e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 121ms/step
# Epoch 26/70
# 22/22 - 3s - loss: 2.5294e-04 - accuracy: 7.1098e-04 - val_loss: 1.0627e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 121ms/step
# Epoch 27/70
# 22/22 - 3s - loss: 2.7726e-04 - accuracy: 7.1098e-04 - val_loss: 1.6278e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 121ms/step
# Epoch 28/70
# 22/22 - 3s - loss: 2.5966e-04 - accuracy: 7.1098e-04 - val_loss: 1.6066e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 122ms/step
# Epoch 29/70
# 22/22 - 3s - loss: 2.7144e-04 - accuracy: 7.1098e-04 - val_loss: 1.8933e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 30/70
# 22/22 - 3s - loss: 2.3977e-04 - accuracy: 7.1098e-04 - val_loss: 2.0361e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 122ms/step
# Epoch 31/70
# 22/22 - 3s - loss: 2.4422e-04 - accuracy: 7.1098e-04 - val_loss: 2.3716e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 32/70
# 22/22 - 3s - loss: 2.1748e-04 - accuracy: 7.1098e-04 - val_loss: 1.0060e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 123ms/step
# Epoch 33/70
# 22/22 - 3s - loss: 2.1569e-04 - accuracy: 7.1098e-04 - val_loss: 1.4468e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 123ms/step
# Epoch 34/70
# 22/22 - 3s - loss: 2.2213e-04 - accuracy: 7.1098e-04 - val_loss: 7.2381e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 123ms/step
# Epoch 35/70
# 22/22 - 3s - loss: 2.4046e-04 - accuracy: 7.1098e-04 - val_loss: 5.4325e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 36/70
# 22/22 - 3s - loss: 2.2683e-04 - accuracy: 7.1098e-04 - val_loss: 7.7493e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 37/70
# 22/22 - 3s - loss: 2.6159e-04 - accuracy: 7.1098e-04 - val_loss: 1.4497e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 125ms/step
# Epoch 38/70
# 22/22 - 3s - loss: 2.3228e-04 - accuracy: 7.1098e-04 - val_loss: 2.0864e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 125ms/step
# Epoch 39/70
# 22/22 - 3s - loss: 2.2494e-04 - accuracy: 7.1098e-04 - val_loss: 5.0164e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 40/70
# 22/22 - 3s - loss: 2.4355e-04 - accuracy: 7.1098e-04 - val_loss: 1.1476e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 41/70
# 22/22 - 3s - loss: 1.8482e-04 - accuracy: 7.1098e-04 - val_loss: 7.6374e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 42/70
# 22/22 - 3s - loss: 1.9040e-04 - accuracy: 7.1098e-04 - val_loss: 1.0790e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 43/70
# 22/22 - 3s - loss: 1.6172e-04 - accuracy: 7.1098e-04 - val_loss: 5.5846e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 125ms/step
# Epoch 44/70
# 22/22 - 3s - loss: 1.8248e-04 - accuracy: 7.1098e-04 - val_loss: 1.2633e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 45/70
# 22/22 - 3s - loss: 2.0881e-04 - accuracy: 7.1098e-04 - val_loss: 1.3993e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 123ms/step
# Epoch 46/70
# 22/22 - 3s - loss: 1.9507e-04 - accuracy: 7.1098e-04 - val_loss: 7.0984e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 47/70
# 22/22 - 3s - loss: 1.6265e-04 - accuracy: 7.1098e-04 - val_loss: 5.1876e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 125ms/step
# Epoch 48/70
# 22/22 - 3s - loss: 1.5800e-04 - accuracy: 7.1098e-04 - val_loss: 6.7110e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 124ms/step
# Epoch 49/70
# 22/22 - 3s - loss: 1.5051e-04 - accuracy: 7.1098e-04 - val_loss: 5.0651e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 50/70
# 22/22 - 3s - loss: 1.4479e-04 - accuracy: 7.1098e-04 - val_loss: 5.1672e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 51/70
# 22/22 - 3s - loss: 1.3394e-04 - accuracy: 7.1098e-04 - val_loss: 6.6236e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 128ms/step
# Epoch 52/70
# 22/22 - 3s - loss: 1.2483e-04 - accuracy: 7.1098e-04 - val_loss: 8.5858e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 127ms/step
# Epoch 53/70
# 22/22 - 3s - loss: 1.5041e-04 - accuracy: 7.1098e-04 - val_loss: 1.7456e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 130ms/step
# Epoch 54/70
# 22/22 - 3s - loss: 1.3284e-04 - accuracy: 7.1098e-04 - val_loss: 4.8759e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 127ms/step
# Epoch 55/70
# 22/22 - 3s - loss: 1.2978e-04 - accuracy: 7.1098e-04 - val_loss: 4.7611e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 56/70
# 22/22 - 3s - loss: 1.5948e-04 - accuracy: 7.1098e-04 - val_loss: 7.3065e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 127ms/step
# Epoch 57/70
# 22/22 - 3s - loss: 1.8700e-04 - accuracy: 7.1098e-04 - val_loss: 5.1849e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 127ms/step
# Epoch 58/70
# 22/22 - 3s - loss: 1.8660e-04 - accuracy: 7.1098e-04 - val_loss: 1.2557e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 59/70
# 22/22 - 3s - loss: 1.8561e-04 - accuracy: 7.1098e-04 - val_loss: 4.3320e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 60/70
# 22/22 - 3s - loss: 1.1665e-04 - accuracy: 7.1098e-04 - val_loss: 4.4241e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 125ms/step
# Epoch 61/70
# 22/22 - 3s - loss: 1.2481e-04 - accuracy: 7.1098e-04 - val_loss: 1.3822e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 127ms/step
# Epoch 62/70
# 22/22 - 3s - loss: 1.1758e-04 - accuracy: 7.1098e-04 - val_loss: 3.8584e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 63/70
# 22/22 - 3s - loss: 1.1753e-04 - accuracy: 7.1098e-04 - val_loss: 3.9992e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 64/70
# 22/22 - 3s - loss: 1.0353e-04 - accuracy: 7.1098e-04 - val_loss: 1.0645e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 142ms/step
# Epoch 65/70
# 22/22 - 3s - loss: 1.5099e-04 - accuracy: 7.1098e-04 - val_loss: 3.3771e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 128ms/step
# Epoch 66/70
# 22/22 - 3s - loss: 1.5164e-04 - accuracy: 7.1098e-04 - val_loss: 1.1321e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 67/70
# 22/22 - 3s - loss: 1.1259e-04 - accuracy: 7.1098e-04 - val_loss: 1.0636e-04 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 68/70
# 22/22 - 3s - loss: 1.4834e-04 - accuracy: 7.1098e-04 - val_loss: 3.8771e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 127ms/step
# Epoch 69/70
# 22/22 - 3s - loss: 1.3460e-04 - accuracy: 7.1098e-04 - val_loss: 8.0767e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step
# Epoch 70/70
# 22/22 - 3s - loss: 1.1066e-04 - accuracy: 7.1098e-04 - val_loss: 5.3217e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 126ms/step

# %%
score= model.evaluate(X_test, y_test, batch_size=256)
# Out:
# 3/3 [==============================] - 0s 37ms/step - loss: 5.3217e-05 - accuracy: 0.0000e+00

# %%
print (score)
# Out:
# [5.321715434547514e-05, 0.0]

# %%
y_pred= model.predict(X_test)
# Out:
# 21/21 [==============================] - 1s 10ms/step

# %%
plt.plot(y_pred, 'r-')
plt.plot(y_test, 'b-')
plt.show()

# %%
import math

# %%
MSE = np.square(np.subtract(y_test,y_pred)).mean() 
print (MSE)
# Out:
# 0.0034791014087449165

# %%
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 0.058983908049101974

# %%
def mae(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs(y_test - y_pred))
print(mae(y_test, y_pred))
# Out:
# 0.04267686614380197

# %%
plt.plot (y_pred, y_test, 'bo')
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.show()
