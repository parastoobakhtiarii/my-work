# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel (r'C:\Users\Parastoo\OneDrive\Desktop\khesapa.xlsx')

# %%
data
# Out:
#           Date  Close  Open  High   Low     Volume
# 0     20220622   1921  1889  1959  1860  280296146
# 1     20220621   1887  1890  1929  1853  159568083
# 2     20220620   1887  1838  1902  1820  352500257
# 3     20220619   1812  1845  1846  1790  166971140
# 4     20220618   1833  1883  1915  1802  182458314
# ...        ...    ...   ...   ...   ...        ...
# 3506  20070627   2745  2692  2745  2692      42104
# 3507  20070626   2746  2693  2746  2693      66263
# 3508  20070625   2747  2695  2747  2695     111180
# 3509  20070624   2749  2697  2749  2697     139490
# 3510  20070623   2752  2714  2752  2714     853036
#
# [3511 rows x 6 columns]

# %%
data= data.dropna(axis=0)
data.tail()
# Out:
#           Date  Close  Open  High   Low  Volume
# 3506  20070627   2745  2692  2745  2692   42104
# 3507  20070626   2746  2693  2746  2693   66263
# 3508  20070625   2747  2695  2747  2695  111180
# 3509  20070624   2749  2697  2749  2697  139490
# 3510  20070623   2752  2714  2752  2714  853036

# %%
plt.figure(figsize=(16,8))
plt.title('khesapa Stocks Closing Price History 1386-1401',fontsize=20)
plt.plot(data['Date'],data['Close'])
plt.xlabel('Date',fontsize=16)
plt.ylabel('Close Price US($)',fontsize=16)
# Out:
# Text(0, 0.5, 'Close Price US($)')

# %%
from stockstats import StockDataFrame as Sdf

# %%
stock = Sdf.retype(data)

# %%
data['macd']=stock['macd']
data.sort_values(by=['date'], inplace=True, ascending=False)
data
# Out:
#           close  open  high   low     volume        macd       macds  \
# date
# 20220622   1921  1889  1959  1860  280296146    0.000000    0.000000
# 20220621   1887  1890  1929  1853  159568083   -0.762821   -0.423789
# 20220620   1887  1838  1902  1820  352500257   -0.971985   -0.648459
# 20220619   1812  1845  1846  1790  166971140   -3.751142   -1.699504
# 20220618   1833  1883  1915  1802  182458314   -4.346686   -2.486981
# ...         ...   ...   ...   ...        ...         ...         ...
# 20070627   2745  2692  2745  2692      42104  300.157001  236.116853
# 20070626   2746  2693  2746  2693      66263  301.959526  249.285387
# 20070625   2747  2695  2747  2695     111180  300.010399  259.430390
# 20070624   2749  2697  2749  2697     139490  295.223927  266.589097
# 20070623   2752  2714  2752  2714     853036  288.348783  270.941034
#
#               macdh
# date
# 20220622   0.000000
# 20220621  -0.339031
# 20220620  -0.323525
# 20220619  -2.051638
# 20220618  -1.859705
# ...             ...
# 20070627  64.040149
# 20070626  52.674139
# 20070625  40.580009
# 20070624  28.634830
# 20070623  17.407749
#
# [3511 rows x 8 columns]

# %%
#data['rsi']=stock['rsi']
#data['rsi']=stock['rsi_14']

# %%
data
# Out:
#           close  open  high   low     volume        macd       macds  \
# date
# 20220622   1921  1889  1959  1860  280296146    0.000000    0.000000
# 20220621   1887  1890  1929  1853  159568083   -0.762821   -0.423789
# 20220620   1887  1838  1902  1820  352500257   -0.971985   -0.648459
# 20220619   1812  1845  1846  1790  166971140   -3.751142   -1.699504
# 20220618   1833  1883  1915  1802  182458314   -4.346686   -2.486981
# ...         ...   ...   ...   ...        ...         ...         ...
# 20070627   2745  2692  2745  2692      42104  300.157001  236.116853
# 20070626   2746  2693  2746  2693      66263  301.959526  249.285387
# 20070625   2747  2695  2747  2695     111180  300.010399  259.430390
# 20070624   2749  2697  2749  2697     139490  295.223927  266.589097
# 20070623   2752  2714  2752  2714     853036  288.348783  270.941034
#
#               macdh
# date
# 20220622   0.000000
# 20220621  -0.339031
# 20220620  -0.323525
# 20220619  -2.051638
# 20220618  -1.859705
# ...             ...
# 20070627  64.040149
# 20070626  52.674139
# 20070625  40.580009
# 20070624  28.634830
# 20070623  17.407749
#
# [3511 rows x 8 columns]

# %%
#data['CCI']=stock['cci']
#data['STCK%']=stock['kdjk']
#data['ADO'] = (data['high'] - data['close'])/(data['high']-data['low'])

# %%
#data

# %%
#data['wr_12']=stock['wr_12']

# %%
data['open_2_sma'] = stock['open_2_sma']
data
# Out:
#           close  open  high   low     volume        macd       macds  \
# date
# 20220622   1921  1889  1959  1860  280296146    0.000000    0.000000
# 20220621   1887  1890  1929  1853  159568083   -0.762821   -0.423789
# 20220620   1887  1838  1902  1820  352500257   -0.971985   -0.648459
# 20220619   1812  1845  1846  1790  166971140   -3.751142   -1.699504
# 20220618   1833  1883  1915  1802  182458314   -4.346686   -2.486981
# ...         ...   ...   ...   ...        ...         ...         ...
# 20070627   2745  2692  2745  2692      42104  300.157001  236.116853
# 20070626   2746  2693  2746  2693      66263  301.959526  249.285387
# 20070625   2747  2695  2747  2695     111180  300.010399  259.430390
# 20070624   2749  2697  2749  2697     139490  295.223927  266.589097
# 20070623   2752  2714  2752  2714     853036  288.348783  270.941034
#
#               macdh  open_2_sma
# date
# 20220622   0.000000      1889.0
# 20220621  -0.339031      1889.5
# 20220620  -0.323525      1864.0
# 20220619  -2.051638      1841.5
# 20220618  -1.859705      1864.0
# ...             ...         ...
# 20070627  64.040149      2691.5
# 20070626  52.674139      2692.5
# 20070625  40.580009      2694.0
# 20070624  28.634830      2696.0
# 20070623  17.407749      2705.5
#
# [3511 rows x 9 columns]

# %%
data.replace([np.inf, -np.inf], np.nan)
data.dropna()
# Out:
#           close  open  high   low     volume        macd       macds  \
# date
# 20220622   1921  1889  1959  1860  280296146    0.000000    0.000000
# 20220621   1887  1890  1929  1853  159568083   -0.762821   -0.423789
# 20220620   1887  1838  1902  1820  352500257   -0.971985   -0.648459
# 20220619   1812  1845  1846  1790  166971140   -3.751142   -1.699504
# 20220618   1833  1883  1915  1802  182458314   -4.346686   -2.486981
# ...         ...   ...   ...   ...        ...         ...         ...
# 20070627   2745  2692  2745  2692      42104  300.157001  236.116853
# 20070626   2746  2693  2746  2693      66263  301.959526  249.285387
# 20070625   2747  2695  2747  2695     111180  300.010399  259.430390
# 20070624   2749  2697  2749  2697     139490  295.223927  266.589097
# 20070623   2752  2714  2752  2714     853036  288.348783  270.941034
#
#               macdh  open_2_sma
# date
# 20220622   0.000000      1889.0
# 20220621  -0.339031      1889.5
# 20220620  -0.323525      1864.0
# 20220619  -2.051638      1841.5
# 20220618  -1.859705      1864.0
# ...             ...         ...
# 20070627  64.040149      2691.5
# 20070626  52.674139      2692.5
# 20070625  40.580009      2694.0
# 20070624  28.634830      2696.0
# 20070623  17.407749      2705.5
#
# [3511 rows x 9 columns]

# %%
data.isnull().any()
# Out:
# close         False
# open          False
# high          False
# low           False
# volume        False
# macd          False
# macds         False
# macdh         False
# open_2_sma    False
# dtype: bool

# %%
#Drop rows with NaN values
#data['open'].dropna()
data.describe()
data = data.dropna(subset=['open'])
data = data.dropna(subset=['high'])
data = data.dropna(subset=['low'])
data = data.dropna(subset=['close'])
#data = data.dropna(subset=['adj close*'])
data = data.dropna(subset=['volume'])
data = data.dropna(subset=['macd'])
data = data.dropna(subset=['macds'])
data = data.dropna(subset=['macdh'])
#data = data.dropna(subset=['rsi'])
#data = data.dropna(subset=['wr_12'])
data = data.dropna(subset=['open_2_sma'])
#data = data.dropna(subset=['CCI'])
#data = data.dropna(subset=['ADO'])
data.isnull().any()
# Out:
# close         False
# open          False
# high          False
# low           False
# volume        False
# macd          False
# macds         False
# macdh         False
# open_2_sma    False
# dtype: bool

# %%
data= data.dropna(axis=0)
data= data.dropna(axis=1)
data.tail()
# Out:
#           close  open  high   low  volume        macd       macds      macdh  \
# date
# 20070627   2745  2692  2745  2692   42104  300.157001  236.116853  64.040149
# 20070626   2746  2693  2746  2693   66263  301.959526  249.285387  52.674139
# 20070625   2747  2695  2747  2695  111180  300.010399  259.430390  40.580009
# 20070624   2749  2697  2749  2697  139490  295.223927  266.589097  28.634830
# 20070623   2752  2714  2752  2714  853036  288.348783  270.941034  17.407749
#
#           open_2_sma
# date
# 20070627      2691.5
# 20070626      2692.5
# 20070625      2694.0
# 20070624      2696.0
# 20070623      2705.5

# %%
data.sort_values(by=['date'], inplace=True, ascending=False)
data
# Out:
#           close  open  high   low     volume        macd       macds  \
# date
# 20220622   1921  1889  1959  1860  280296146    0.000000    0.000000
# 20220621   1887  1890  1929  1853  159568083   -0.762821   -0.423789
# 20220620   1887  1838  1902  1820  352500257   -0.971985   -0.648459
# 20220619   1812  1845  1846  1790  166971140   -3.751142   -1.699504
# 20220618   1833  1883  1915  1802  182458314   -4.346686   -2.486981
# ...         ...   ...   ...   ...        ...         ...         ...
# 20070627   2745  2692  2745  2692      42104  300.157001  236.116853
# 20070626   2746  2693  2746  2693      66263  301.959526  249.285387
# 20070625   2747  2695  2747  2695     111180  300.010399  259.430390
# 20070624   2749  2697  2749  2697     139490  295.223927  266.589097
# 20070623   2752  2714  2752  2714     853036  288.348783  270.941034
#
#               macdh  open_2_sma
# date
# 20220622   0.000000      1889.0
# 20220621  -0.339031      1889.5
# 20220620  -0.323525      1864.0
# 20220619  -2.051638      1841.5
# 20220618  -1.859705      1864.0
# ...             ...         ...
# 20070627  64.040149      2691.5
# 20070626  52.674139      2692.5
# 20070625  40.580009      2694.0
# 20070624  28.634830      2696.0
# 20070623  17.407749      2705.5
#
# [3511 rows x 9 columns]

# %%
#data.columns = [ 'high', 'low' ,'open' , 'macd' , 'macds' , 'macdh' , 'rsi'  , 'CCI'  , 'ADO' , 'open_sma' , 'wr_12', 'close' , 'volume'  ]
#data

# %%
from keras.layers import Dense, Dropout, Activation, LSTM, Convolution1D, MaxPooling1D, Flatten
from keras.models import Sequential

# %%
data= data.values[:, 0:9]
print (data.shape)
# Out:
# (3511, 9)

# %%
print (data[:9, :])
# Out:
# [[ 1.92100000e+03  1.88900000e+03  1.95900000e+03  1.86000000e+03
#    2.80296146e+08  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    1.88900000e+03]
#  [ 1.88700000e+03  1.89000000e+03  1.92900000e+03  1.85300000e+03
#    1.59568083e+08 -7.62820513e-01 -4.23789174e-01 -3.39031339e-01
#    1.88950000e+03]
#  [ 1.88700000e+03  1.83800000e+03  1.90200000e+03  1.82000000e+03
#    3.52500257e+08 -9.71984743e-01 -6.48459489e-01 -3.23525254e-01
#    1.86400000e+03]
#  [ 1.81200000e+03  1.84500000e+03  1.84600000e+03  1.79000000e+03
#    1.66971140e+08 -3.75114229e+00 -1.69950380e+00 -2.05163849e+00
#    1.84150000e+03]
#  [ 1.83300000e+03  1.88300000e+03  1.91500000e+03  1.80200000e+03
#    1.82458314e+08 -4.34668562e+00 -2.48698054e+00 -1.85970507e+00
#    1.86400000e+03]
#  [ 1.88300000e+03  1.90000000e+03  1.91700000e+03  1.86400000e+03
#    1.52004429e+08 -2.48495540e+00 -2.48643162e+00  1.47621227e-03
#    1.89150000e+03]
#  [ 1.93300000e+03  1.91900000e+03  1.98900000e+03  1.88300000e+03
#    3.24425843e+08  1.01687707e+00 -1.59983765e+00  2.61671471e+00
#    1.90950000e+03]
#  [ 1.90500000e+03  1.84400000e+03  1.90900000e+03  1.84400000e+03
#    4.71168460e+08  2.01693857e+00 -7.30658310e-01  2.74759688e+00
#    1.88150000e+03]
#  [ 1.81900000e+03  1.76600000e+03  1.86600000e+03  1.74600000e+03
#    2.29312432e+08 -1.58799927e+00 -9.28708325e-01 -6.59290944e-01
#    1.80500000e+03]]

# %%
y= data[0:, 0]
print (y.shape)
X= data[:3511,:]
print (X.shape)
y
# Out:
# (3511,)
# (3511, 9)
# array([1921., 1887., 1887., ..., 2747., 2749., 2752.])

# %%
X
# Out:
# array([[ 1.92100000e+03,  1.88900000e+03,  1.95900000e+03, ...,
#          0.00000000e+00,  0.00000000e+00,  1.88900000e+03],
#        [ 1.88700000e+03,  1.89000000e+03,  1.92900000e+03, ...,
#         -4.23789174e-01, -3.39031339e-01,  1.88950000e+03],
#        [ 1.88700000e+03,  1.83800000e+03,  1.90200000e+03, ...,
#         -6.48459489e-01, -3.23525254e-01,  1.86400000e+03],
#        ...,
#        [ 2.74700000e+03,  2.69500000e+03,  2.74700000e+03, ...,
#          2.59430390e+02,  4.05800091e+01,  2.69400000e+03],
#        [ 2.74900000e+03,  2.69700000e+03,  2.74900000e+03, ...,
#          2.66589097e+02,  2.86348296e+01,  2.69600000e+03],
#        [ 2.75200000e+03,  2.71400000e+03,  2.75200000e+03, ...,
#          2.70941034e+02,  1.74077485e+01,  2.70550000e+03]])

# %%
y= (y- min(y))/(max(y)- min(y))
print (y[3504:])
print (y[:7])
# Out:
# [0.39398085 0.40414305 0.41469611 0.41489154 0.41508697 0.41547782
#  0.4160641 ]
# [0.25366426 0.24701974 0.24701974 0.23236271 0.23646668 0.24623803
#  0.25600938]

# %%
print(np.min(X,axis=0))
# Out:
# [ 623.            0.            0.            0.            0.
#  -562.37713802 -535.05782827 -186.48167843    0.        ]

# %%
X= (X- np.min(X,axis=0))/(np.max(X, axis=0)-np.min(X,axis=0))
#X= (X- np.min(X))/(np.max(X)-np.min(X))
print (X.shape)
print (X[:3, :])
# Out:
# (3511, 9)
# [[0.25366426 0.32795139 0.32541528 0.3363472  0.07437316 0.46868157
#   0.4956353  0.35360702 0.33552398]
#  [0.24701974 0.328125   0.32043189 0.33508137 0.04233944 0.46804584
#   0.49524274 0.35296415 0.33561279]
#  [0.24701974 0.31909722 0.31594684 0.32911392 0.09353164 0.46787152
#   0.49503462 0.35299355 0.33108348]]

# %%
time_steps= 50
X_new= np.zeros((X.shape[0] - time_steps +1, 100, X.shape[1]))
y_new= np.zeros((y.shape[0] -time_steps +1,))
for ix in range(X_new.shape[0]):
    for jx in range(time_steps):
        X_new[ix, jx, :]= X[ix +jx, :]
    y_new[ix]= y[ix + time_steps -1]
print (X_new.shape, y_new.shape)
# Out:
# (3462, 100, 9) (3462,)

# %%
split = int(0.8*data.shape[0])
X_train = X_new[:split]
X_test = X_new[split:]

y_train = y_new[:split]
y_test = y_new[split:]

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (2808, 100, 9) (2808,)
# (654, 100, 9) (654,)

# %%
model = Sequential()
model.add(Convolution1D(64, 3, padding='same',input_shape= (100,9)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.2))
model.add(Convolution1D(32, 3, padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(units=1))
model.add(Activation('linear'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 100, 64)           1792
#
#  max_pooling1d_8 (MaxPooling  (None, 50, 64)           0
#  1D)
#
#  lstm_4 (LSTM)               (None, 50, 100)           66000
#
#  dropout_4 (Dropout)         (None, 50, 100)           0
#
#  conv1d_9 (Conv1D)           (None, 50, 32)            9632
#
#  max_pooling1d_9 (MaxPooling  (None, 25, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (None, 800)               0
#
#  dense_4 (Dense)             (None, 1)                 801
#
#  activation_4 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 78,225
# Trainable params: 78,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
history= model.fit(X_train, y_train, batch_size=128, epochs=100, validation_data = (X_test, y_test), verbose=2)
# Out:
# Epoch 1/100
# 22/22 - 6s - loss: 0.0151 - accuracy: 0.0100 - val_loss: 0.0024 - val_accuracy: 0.0000e+00 - 6s/epoch - 260ms/step
# Epoch 2/100
# 22/22 - 2s - loss: 0.0040 - accuracy: 0.0103 - val_loss: 0.0029 - val_accuracy: 0.0000e+00 - 2s/epoch - 101ms/step
# Epoch 3/100
# 22/22 - 2s - loss: 0.0023 - accuracy: 0.0103 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - 2s/epoch - 103ms/step
# Epoch 4/100
# 22/22 - 2s - loss: 0.0016 - accuracy: 0.0103 - val_loss: 9.8149e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 104ms/step
# Epoch 5/100
# 22/22 - 2s - loss: 0.0013 - accuracy: 0.0103 - val_loss: 6.2089e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 104ms/step
# Epoch 6/100
# 22/22 - 2s - loss: 9.9896e-04 - accuracy: 0.0103 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - 2s/epoch - 104ms/step
# Epoch 7/100
# 22/22 - 2s - loss: 9.2684e-04 - accuracy: 0.0103 - val_loss: 4.3071e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 105ms/step
# Epoch 8/100
# 22/22 - 2s - loss: 7.8340e-04 - accuracy: 0.0103 - val_loss: 2.8923e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 106ms/step
# Epoch 9/100
# 22/22 - 2s - loss: 7.7402e-04 - accuracy: 0.0103 - val_loss: 4.1622e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 106ms/step
# Epoch 10/100
# 22/22 - 2s - loss: 7.2486e-04 - accuracy: 0.0103 - val_loss: 2.5565e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 105ms/step
# Epoch 11/100
# 22/22 - 2s - loss: 6.7255e-04 - accuracy: 0.0103 - val_loss: 2.2906e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 105ms/step
# Epoch 12/100
# 22/22 - 2s - loss: 6.2767e-04 - accuracy: 0.0103 - val_loss: 6.2090e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 107ms/step
# Epoch 13/100
# 22/22 - 2s - loss: 6.0894e-04 - accuracy: 0.0103 - val_loss: 1.4602e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 14/100
# 22/22 - 2s - loss: 5.3215e-04 - accuracy: 0.0103 - val_loss: 3.5857e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 15/100
# 22/22 - 2s - loss: 5.0444e-04 - accuracy: 0.0103 - val_loss: 2.2470e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 107ms/step
# Epoch 16/100
# 22/22 - 2s - loss: 4.5326e-04 - accuracy: 0.0103 - val_loss: 1.9963e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 17/100
# 22/22 - 2s - loss: 4.2231e-04 - accuracy: 0.0103 - val_loss: 2.9003e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 18/100
# 22/22 - 2s - loss: 4.1261e-04 - accuracy: 0.0103 - val_loss: 9.7676e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 19/100
# 22/22 - 2s - loss: 4.4499e-04 - accuracy: 0.0103 - val_loss: 1.0560e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 20/100
# 22/22 - 2s - loss: 4.1574e-04 - accuracy: 0.0103 - val_loss: 1.0782e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 21/100
# 22/22 - 2s - loss: 4.0189e-04 - accuracy: 0.0103 - val_loss: 8.4639e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 22/100
# 22/22 - 2s - loss: 4.2667e-04 - accuracy: 0.0103 - val_loss: 1.3442e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 23/100
# 22/22 - 2s - loss: 3.7285e-04 - accuracy: 0.0103 - val_loss: 2.0031e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 107ms/step
# Epoch 24/100
# 22/22 - 2s - loss: 3.3103e-04 - accuracy: 0.0103 - val_loss: 1.0051e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 25/100
# 22/22 - 2s - loss: 2.8486e-04 - accuracy: 0.0103 - val_loss: 9.1387e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 26/100
# 22/22 - 2s - loss: 3.2399e-04 - accuracy: 0.0103 - val_loss: 1.5781e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 27/100
# 22/22 - 2s - loss: 2.5493e-04 - accuracy: 0.0103 - val_loss: 8.8496e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 28/100
# 22/22 - 2s - loss: 2.6531e-04 - accuracy: 0.0103 - val_loss: 8.4177e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 112ms/step
# Epoch 29/100
# 22/22 - 2s - loss: 2.3479e-04 - accuracy: 0.0103 - val_loss: 1.7570e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 111ms/step
# Epoch 30/100
# 22/22 - 2s - loss: 2.5396e-04 - accuracy: 0.0103 - val_loss: 6.0895e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 31/100
# 22/22 - 2s - loss: 2.5303e-04 - accuracy: 0.0103 - val_loss: 1.3300e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 32/100
# 22/22 - 2s - loss: 2.8666e-04 - accuracy: 0.0103 - val_loss: 1.0137e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 33/100
# 22/22 - 2s - loss: 2.5052e-04 - accuracy: 0.0103 - val_loss: 5.9552e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 107ms/step
# Epoch 34/100
# 22/22 - 2s - loss: 2.5021e-04 - accuracy: 0.0103 - val_loss: 6.3273e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 105ms/step
# Epoch 35/100
# 22/22 - 2s - loss: 2.0798e-04 - accuracy: 0.0103 - val_loss: 1.1367e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 106ms/step
# Epoch 36/100
# 22/22 - 2s - loss: 2.2208e-04 - accuracy: 0.0103 - val_loss: 5.4137e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 107ms/step
# Epoch 37/100
# 22/22 - 2s - loss: 1.8502e-04 - accuracy: 0.0103 - val_loss: 1.0191e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 107ms/step
# Epoch 38/100
# 22/22 - 2s - loss: 1.9837e-04 - accuracy: 0.0103 - val_loss: 7.3193e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 107ms/step
# Epoch 39/100
# 22/22 - 2s - loss: 1.9636e-04 - accuracy: 0.0103 - val_loss: 3.9298e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 40/100
# 22/22 - 3s - loss: 1.7590e-04 - accuracy: 0.0103 - val_loss: 7.3822e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 118ms/step
# Epoch 41/100
# 22/22 - 3s - loss: 1.8131e-04 - accuracy: 0.0103 - val_loss: 5.4809e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 115ms/step
# Epoch 42/100
# 22/22 - 3s - loss: 1.6955e-04 - accuracy: 0.0103 - val_loss: 5.6552e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 114ms/step
# Epoch 43/100
# 22/22 - 2s - loss: 1.6386e-04 - accuracy: 0.0103 - val_loss: 1.0094e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 44/100
# 22/22 - 2s - loss: 1.4858e-04 - accuracy: 0.0103 - val_loss: 3.5058e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 45/100
# 22/22 - 2s - loss: 1.7194e-04 - accuracy: 0.0103 - val_loss: 4.4842e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 107ms/step
# Epoch 46/100
# 22/22 - 2s - loss: 1.4729e-04 - accuracy: 0.0103 - val_loss: 8.1492e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 47/100
# 22/22 - 2s - loss: 1.5721e-04 - accuracy: 0.0103 - val_loss: 3.1133e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 48/100
# 22/22 - 2s - loss: 1.3795e-04 - accuracy: 0.0103 - val_loss: 9.2864e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 49/100
# 22/22 - 2s - loss: 1.3796e-04 - accuracy: 0.0103 - val_loss: 4.9020e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 50/100
# 22/22 - 2s - loss: 1.3556e-04 - accuracy: 0.0103 - val_loss: 4.9426e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 51/100
# 22/22 - 2s - loss: 1.1523e-04 - accuracy: 0.0103 - val_loss: 1.1392e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 52/100
# 22/22 - 2s - loss: 1.3191e-04 - accuracy: 0.0103 - val_loss: 6.2588e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 53/100
# 22/22 - 2s - loss: 1.2417e-04 - accuracy: 0.0103 - val_loss: 3.9511e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 54/100
# 22/22 - 2s - loss: 1.2049e-04 - accuracy: 0.0103 - val_loss: 2.6925e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 55/100
# 22/22 - 2s - loss: 1.3621e-04 - accuracy: 0.0103 - val_loss: 1.1080e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 56/100
# 22/22 - 2s - loss: 1.3227e-04 - accuracy: 0.0103 - val_loss: 4.8545e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 57/100
# 22/22 - 2s - loss: 1.1508e-04 - accuracy: 0.0103 - val_loss: 2.8302e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 105ms/step
# Epoch 58/100
# 22/22 - 2s - loss: 1.1191e-04 - accuracy: 0.0103 - val_loss: 3.0159e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 59/100
# 22/22 - 2s - loss: 1.0508e-04 - accuracy: 0.0103 - val_loss: 5.6878e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 60/100
# 22/22 - 2s - loss: 9.8988e-05 - accuracy: 0.0103 - val_loss: 2.7709e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 112ms/step
# Epoch 61/100
# 22/22 - 2s - loss: 9.6756e-05 - accuracy: 0.0103 - val_loss: 1.9929e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 112ms/step
# Epoch 62/100
# 22/22 - 2s - loss: 1.2211e-04 - accuracy: 0.0103 - val_loss: 7.0099e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 111ms/step
# Epoch 63/100
# 22/22 - 2s - loss: 1.0887e-04 - accuracy: 0.0103 - val_loss: 2.4086e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 112ms/step
# Epoch 64/100
# 22/22 - 3s - loss: 8.9803e-05 - accuracy: 0.0103 - val_loss: 8.2259e-05 - val_accuracy: 0.0000e+00 - 3s/epoch - 123ms/step
# Epoch 65/100
# 22/22 - 2s - loss: 1.0736e-04 - accuracy: 0.0103 - val_loss: 2.7864e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 66/100
# 22/22 - 2s - loss: 1.1622e-04 - accuracy: 0.0103 - val_loss: 1.0612e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 111ms/step
# Epoch 67/100
# 22/22 - 2s - loss: 8.9167e-05 - accuracy: 0.0103 - val_loss: 2.0287e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 68/100
# 22/22 - 2s - loss: 8.6698e-05 - accuracy: 0.0103 - val_loss: 8.4240e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 69/100
# 22/22 - 2s - loss: 9.3810e-05 - accuracy: 0.0103 - val_loss: 8.0293e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 70/100
# 22/22 - 2s - loss: 9.2502e-05 - accuracy: 0.0103 - val_loss: 2.8877e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 71/100
# 22/22 - 2s - loss: 9.9734e-05 - accuracy: 0.0103 - val_loss: 5.4827e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 72/100
# 22/22 - 2s - loss: 1.2100e-04 - accuracy: 0.0103 - val_loss: 1.8859e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 73/100
# 22/22 - 2s - loss: 8.9380e-05 - accuracy: 0.0103 - val_loss: 4.5561e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 74/100
# 22/22 - 2s - loss: 7.4801e-05 - accuracy: 0.0103 - val_loss: 1.3564e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 75/100
# 22/22 - 2s - loss: 9.6369e-05 - accuracy: 0.0103 - val_loss: 4.3265e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 76/100
# 22/22 - 2s - loss: 8.9607e-05 - accuracy: 0.0103 - val_loss: 1.4824e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 77/100
# 22/22 - 2s - loss: 1.8002e-04 - accuracy: 0.0103 - val_loss: 1.3525e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 78/100
# 22/22 - 2s - loss: 1.5188e-04 - accuracy: 0.0103 - val_loss: 1.5388e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 111ms/step
# Epoch 79/100
# 22/22 - 2s - loss: 1.0082e-04 - accuracy: 0.0103 - val_loss: 1.3489e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 111ms/step
# Epoch 80/100
# 22/22 - 2s - loss: 8.3189e-05 - accuracy: 0.0103 - val_loss: 2.7202e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 81/100
# 22/22 - 2s - loss: 7.1312e-05 - accuracy: 0.0103 - val_loss: 3.6192e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 82/100
# 22/22 - 2s - loss: 7.0919e-05 - accuracy: 0.0103 - val_loss: 4.4966e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 83/100
# 22/22 - 2s - loss: 6.3736e-05 - accuracy: 0.0103 - val_loss: 1.5862e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 112ms/step
# Epoch 84/100
# 22/22 - 2s - loss: 6.0981e-05 - accuracy: 0.0103 - val_loss: 7.1291e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 111ms/step
# Epoch 85/100
# 22/22 - 2s - loss: 8.4695e-05 - accuracy: 0.0103 - val_loss: 1.1310e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 113ms/step
# Epoch 86/100
# 22/22 - 2s - loss: 9.1345e-05 - accuracy: 0.0103 - val_loss: 1.0993e-04 - val_accuracy: 0.0000e+00 - 2s/epoch - 111ms/step
# Epoch 87/100
# 22/22 - 2s - loss: 6.7626e-05 - accuracy: 0.0103 - val_loss: 4.2248e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 113ms/step
# Epoch 88/100
# 22/22 - 2s - loss: 6.5668e-05 - accuracy: 0.0103 - val_loss: 1.1463e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 89/100
# 22/22 - 2s - loss: 5.8839e-05 - accuracy: 0.0103 - val_loss: 2.0002e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 90/100
# 22/22 - 2s - loss: 7.7684e-05 - accuracy: 0.0103 - val_loss: 1.9294e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 91/100
# 22/22 - 2s - loss: 7.4280e-05 - accuracy: 0.0103 - val_loss: 1.1807e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 92/100
# 22/22 - 2s - loss: 6.4454e-05 - accuracy: 0.0103 - val_loss: 9.9614e-06 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 93/100
# 22/22 - 2s - loss: 7.1489e-05 - accuracy: 0.0103 - val_loss: 1.2752e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 108ms/step
# Epoch 94/100
# 22/22 - 2s - loss: 6.3711e-05 - accuracy: 0.0103 - val_loss: 2.7234e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 107ms/step
# Epoch 95/100
# 22/22 - 2s - loss: 5.4063e-05 - accuracy: 0.0103 - val_loss: 1.4230e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 109ms/step
# Epoch 96/100
# 22/22 - 2s - loss: 5.6704e-05 - accuracy: 0.0103 - val_loss: 1.8032e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 110ms/step
# Epoch 97/100
# 22/22 - 2s - loss: 5.7372e-05 - accuracy: 0.0103 - val_loss: 8.5750e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 111ms/step
# Epoch 98/100
# 22/22 - 2s - loss: 6.7041e-05 - accuracy: 0.0103 - val_loss: 1.9885e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 112ms/step
# Epoch 99/100
# 22/22 - 2s - loss: 5.5332e-05 - accuracy: 0.0103 - val_loss: 1.0131e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 111ms/step
# Epoch 100/100
# 22/22 - 2s - loss: 5.3026e-05 - accuracy: 0.0103 - val_loss: 1.2065e-05 - val_accuracy: 0.0000e+00 - 2s/epoch - 112ms/step

# %%
score= model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 6/6 [==============================] - 0s 38ms/step - loss: 1.2065e-05 - accuracy: 0.0000e+00

# %%
print (score)
# Out:
# [1.2064859220117796e-05, 0.0]

# %%
y_pred= model.predict(X_test)
# Out:
# 21/21 [==============================] - 1s 17ms/step

# %%
plt.plot(y_pred, 'r-')
plt.plot(y_test, 'b-')
plt.show()

# %%
import math

# %%
MSE = np.square(np.subtract(y_test,y_pred)).mean() 
print (MSE)
# Out:
# 0.007747126417407387

# %%
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 0.0880177619427317

# %%
def mae(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs(y_test - y_pred))
print(mae(y_test, y_pred))
# Out:
# 0.06716444715151028

# %%
plt.plot (y_pred, y_test, 'bo')
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.show()

# %%
#plt.figure(figsize=(7, 5))
plt.plot(history.epoch, history.history['loss'], lw=3, label='Training')
plt.plot(history.epoch, history.history['val_loss'], lw=3, label='Testing')
plt.legend(fontsize=14)
plt.title('Loss as a function of epoch', fontsize=16)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.tight_layout()
